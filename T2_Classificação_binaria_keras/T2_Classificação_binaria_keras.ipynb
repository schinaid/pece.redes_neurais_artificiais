# %% [markdown]
# # Trabalho #2 - Classificação binária com rede neural deep-learning
#
# Nesse trabalho você vai desenvolver uma rede neural rasa e uma deep-learning, usando a plataforma TensorFlow-Keras, para realizar uma tarefa de classificação binária para reconhecer gatos em imagens e comparar o desempenho das duas redes.

# %% [markdown]
# ## Identificação
#
# Nome: Anderson Alves Schinaid

# %% [markdown]
# ## 1 - Bibliotecas ##
#
# Em primeiro lugar, execute a célula abaixo para importar algumas bibliotecas Python que são usadas nesse trabalho.
# - [numpy](www.numpy.org) é a biblioteca básica para computação cinetífica usando Python.
# - [h5py](http://www.h5py.org) é uma biblioteca que fornece funções para interagir com banco de dados salvos em arquivos no formato h5.
# - [matplotlib](http://matplotlib.org) é uma biblioteca famosa usada para fazer gráficos com Python.
# - [PIL](http://www.pythonware.com/products/pil/) e [scipy](https://www.scipy.org/) são usadas para testar a sua RNA com novas imagens no final do trabalho.
# - lr_utils é um arquivo com uma função para ler os dados usados nesse trabalho.

# %% [markdown]
# O comando da célula abaixo importa o TensorFlow e verifica a versão que está sendo utilizada.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# Como o TensorFlow é um software aberto não existe muita preocupação do desenvolvedor (no caso o Google) de manter a compatibilidade entre as versões. Assim, se você estiver usando uma versão do TensorFlow incompatível com o seu programa, você pode impor o uso de uma versão mais antiga.
#
# Por exemplo o código abaixo importa a versão 2 do TensorFlow, mas se ela não estiver instalada importa a versão instalada.
#
# ```
#  try:
#      import tensorflow.compat.v2 as tf
#  except Exception:
#      import tensorflow as tf
#  print(tf.__version__)
# ```
#
# Outro exemplo, se a versão instalada do TensorFlow for a 2 e o seu programa foi feito para a versão 1, então pode habilitar a versão 2 com o comportamento da versão 1. O código abaixo mostra como fazer isso.
#
# ```
#  import tensorflow as tf
#  print(tf.__version__)
#  tf.enable_v1_behavior()
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage

# %matplotlib inline

# %% [markdown]
# ## 2 - Visão geral do problema ##
#
# **Definição do problema**:
#
# Nesse trabalho é fornecido um conjunto de dados que contém:
#
#     - um conjunto de imagens de treinamento classificadas como tendo gato (y=1) ou não tendo gato (y=0);
#     - um conjunto de imagens de teste classificadas como tendo gato (y=1) ou não tendo gato (y=0);
#     - a dimensão de cada imagem é (num_px, num_px, 3), onde 3 é o número de canais de cor (RGB);
#     - cada imagem é composta por três matrizes de dimensão: número de linhas = num_px e número de colunas = num_px;
#     - número de imagens do conjunto de treinamento: m_train;
#     - número de imagens do conjunto de teste: m_test.
#
# A partir desses conjuntos de dados, a sua tarefa é desenvolver um sistema baseado em uma rede neural, para processar imagens e classificar corretamente se ela mostra ou não um gato. Para isso, você vai desenvolver algumas redes neurais usando a ferramenta Keras e comparar o desempenho delas.
#
# O uso da ferramenta Keras para desenvolver redes neurais facilita muito o trabalho, pois não exige desenvolver codigos específicos para implementar cada camada da rede, a função de custo, a métrica e principalmente o gradiente descendente.

# %% [markdown]
# ## 3 - Conjunto de dados de treinamento e teste
#
# O conjunto de dados utilizado pode ser obtido em: https://www.kaggle.com/mriganksingh/cat-images-dataset. Para carregar esse conjunto de dados execute o código a seguir.
#
# O termo _orig é adicionado no final dos tensores com os dados de treinamento e teste originais porque vamos processar esses dados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Conjunto de dados de treinamento
path = '/content/drive/MyDrive/PECE/Redes neurais artificiais/T2_Classificação_binaria_keras/'
train_dataset = h5py.File(path + 'train_catvnoncat.h5', "r")
train_set_x_orig = np.array(train_dataset["train_set_x"][:])
train_set_y = np.array(train_dataset["train_set_y"][:])

# Conjunto de dados de teste
test_dataset = h5py.File(path + 'test_catvnoncat.h5', "r")
test_set_x_orig = np.array(test_dataset["test_set_x"][:])
test_set_y = np.array(test_dataset["test_set_y"][:])

# Acerta dimensões das saídas
train_set_y = train_set_y.reshape((1, train_set_y.shape[0]))
test_set_y = test_set_y.reshape((1, test_set_y.shape[0]))

classes = np.array(test_dataset["list_classes"][:]) # the list of classes

# %%
# Examplo de uma imagem
index = 11
print(train_set_x_orig[index].shape)
plt.imshow(train_set_x_orig[index])
print ("y = " + str(train_set_y[:, index]) + ", it's a '" + classes[np.squeeze(train_set_y[:, index])].decode("utf-8") +  "' picture.")
# Out:
# (64, 64, 3)
# y = [1], it's a 'cat' picture.

# %% [markdown]
# No código acima index é o número sequencial da imagem. Tente trocar a imagem, mudando o index, usando valores entre 0 e 208, para visualizar outros exemplos.

# %% [markdown]
# ### 3.1 - Determinação do formato e dimensões dos dados
#
# ### Exercício #1:
#
# É importante conhecer as dimensões dos dados que estamos trabalhando para evitar problemas. Assim, obtenha os valores dos seguintes parâmetros:
#     - m_train = número de exemplos de treinamento;
#     - m_test = número de exemplos de teste;
#     - num_px = altura e largura das imagens (as imagens são quadradas).
#
# Lembre que `train_set_x_orig` é um tensor numpy de dimensão (m_train, num_px, num_px, 3). Por exemplo, você pode obter  `m_train` escrevendo `train_set_x_orig.shape[0]`.

# %%
# PARA VOCÊ FAZER:

### COMECE AQUIE ### (≈ 3 linhas)
m_train = train_set_x_orig.shape[0]
m_test = test_set_x_orig.shape[0]
num_px = train_set_x_orig.shape[1]
### TERMINE AQUI ###

print ("Número de exemplos de treinamento: m_train = " + str(m_train))
print ("Número de exemplos de teste: m_test = " + str(m_test))
print ("Altura/largura de cada imagem: num_px = " + str(num_px))
print ("Dimensão de cada imagem: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("Dimensão - train_set_x: " + str(train_set_x_orig.shape))
print ("Dimensão - train_set_y: " + str(train_set_y.shape))
print ("Dimensão - test_set_x: " + str(test_set_x_orig.shape))
print ("Dimensão - test_set_y: " + str(test_set_y.shape))
# Out:
# Número de exemplos de treinamento: m_train = 209
# Número de exemplos de teste: m_test = 50
# Altura/largura de cada imagem: num_px = 64
# Dimensão de cada imagem: (64, 64, 3)
# Dimensão - train_set_x: (209, 64, 64, 3)
# Dimensão - train_set_y: (1, 209)
# Dimensão - test_set_x: (50, 64, 64, 3)
# Dimensão - test_set_y: (1, 50)

# %% [markdown]
# **Saída esperada para m_train, m_test e num_px**:
#
#     Número de exemplos de treinamento: m_train = 209
#     Número de exemplos de teste: m_test = 50
#     Altura/largura de cada imagem: num_px = 64
#     Dimensão de cada imagem: (64, 64, 3)
#     Dimensão - train_set_x: (209, 64, 64, 3)
#     Dimensão - train_set_y: (1, 209)
#     Dimensão - test_set_x: (50, 64, 64, 3)
#     >Dimensão - test_set_y: (1, 50)
#
# Observe que o primeiro eixo dos tensores com as imagens dos conjuntos de teste e de treinamento representa os exemplos, da forma como é esperado para os dados no Keras.

# %% [markdown]
# ### 3.2 - Processamento dos dados
#
# Os dados dos exemplos de treinamento e de teste devem ser processados de forma a serem colocados em tensores com as dimensões adequadas e normalizados corretamente. Nos exercícios que seguem você irá realizar o processamento dos dados de forma a poderem ser usados na sua RNA implementada com o Keras.

# %% [markdown]
# ### Redimensionamento dos dados
#
# Os dados de entrada de uma camada de neurônios densa é um vetor, assim, devemos redimensionar as imagens, que tem dimensão (num_px, num_px, 3), para transformá-las em um vetor linha de dimensão (1, num_px∗num_px∗3). Após esse redimensionamento o conjunto de dados é um tensor numpy onde cada linha representa uma imagem "esticada". O tensor com as entradas dos dados de treinamento terá m_train linhas e o de teste m_test linhas.
#
# Por exemplo, para redimensionar uma matriz de dimensão (a,b,c,d) para uma matriz de dimensão (a, b∗c∗d) pode-se usar o seguinte código Python:
#
#     X_flatten = X.reshape((a, b∗c∗d))
#
# A dimensão dos dados de saída também deve ser alterada porque, como visto, o Keras espara que os exemplos representam o primeiro eixo do tensor e nos dados de saída os exemplos representam o segundo eixo. Assim, os vetores com os dados de saída, tanto de treinamento como de teste, devem ser transpostos.

# %% [markdown]
# ### Exercício #2:
#
# Implemente o redimensionamento dos dados de entrada na célula a seguir.

# %%
# PARA VOCÊ FAZER: redimensionamento das imagens dos exemplos de treinamento e teste

### COMECE AQUI ### (≈ 2 linhas)
# Redimensionamento dos dados de entrada
train_set_x_flatten = train_set_x_orig.reshape(train_set_x_orig.shape[0], -1)
test_set_x_flatten = test_set_x_orig.reshape(test_set_x_orig.shape[0], -1)
### TERMINE AQUI ###

### COMECE AQUI ### (≈ 2 linhas)
# Redimensionamento dos dados de saída (transposição)
train_set_y = train_set_y.reshape(-1, 1)
test_set_y = test_set_y.reshape(-1, 1)
### TERMINE AQUI ###

print ("Dimensão - train_set_x_flatten: " + str(train_set_x_flatten.shape))
print ("Dimensão - train_set_y: " + str(train_set_y.shape))
print ("Dimensão - test_set_x_flatten: " + str(test_set_x_flatten.shape))
print ("Dimensão - test_set_y: " + str(test_set_y.shape))
print ("Verificação de valores após redimensionamento: " + str(train_set_x_flatten[0,0:5]))
# Out:
# Dimensão - train_set_x_flatten: (209, 12288)
# Dimensão - train_set_y: (209, 1)
# Dimensão - test_set_x_flatten: (50, 12288)
# Dimensão - test_set_y: (50, 1)
# Verificação de valores após redimensionamento: [17 31 56 22 33]

# %% [markdown]
# **Saída esperada**:
#
#     Dimensão - train_set_x_flatten: (209, 12288)
#     Dimensão - train_set_y: (209, 1)
#     Dimensão - test_set_x_flatten: (50, 12288)
#     Dimensão - test_set_y: (50, 1)
#     Verificação de valores após redimensionamento: [17 31 56 22 33]

# %% [markdown]
# ### Normalização dos dados
#
# Nas imagens coloridas as cores vermelho, verde e azul (RGB) são especificadas para cada pixel da imagem, de forma que cada pixel consite de um vetor de tres números que variam no intervalo de 0 a 255.
#
# Uma etapa do processamento dos dados é normalizar esses dados de forma a ter dados com média zero e desvio padrão um. No caso de imagens o processo de normalização dos dados é mais simples e consiste simplesmente em dividir todos os valores da imagem por 255, que é o valor máximo de um pixel.
#
# ### Exercício #3:
#
# Implemente a normalização dos dados de forma a ter todas os elementos dos dados de entrada entre 0 e 1.

# %%
# PARA VOCÊ FAZER: redimensionamento das imagens dos exemplos de treinamento e teste

### COMECE AQUI ### (≈ 2 linhas)
train_set_x = train_set_x_flatten / 255.0
test_set_x = test_set_x_flatten / 255.0
### TERMINE AQUI ###

print ("Máximo valor de train_set_x: " + str(np.max(train_set_x)))
print ("Máximo valor de train_set_x: " + str(np.max(test_set_x)))
# Out:
# Máximo valor de train_set_x: 1.0
# Máximo valor de train_set_x: 1.0

# %% [markdown]
# **Saída esperada**:
#
#     Máximo valor de train_set_x: 1.0
#     Máximo valor de train_set_x: 1.0

# %% [markdown]
# <font color='blue'>
#
# **O que é importante lembrar:**
#
# As etapas principais do processamento de dados são as seguintes:
# - Verificar a dimensão e formato dos dados do problema. Nesse caso são: m_train, m_test, num_px, ...
# - Redimensionar os conjuntos de dados. Nesse caso para cada exemplo a entrada é um vetor linha de dimensão (1, num_px \* num_px \* 3)
# - Normalizar os dados

# %% [markdown]
# ## 4 - Desenvolvimento e teste da rede neural rasa
#
# Nesse trabalho vamos testar diferentes redes neurais, variando numero de camadas, numero de neurônios nas camadas e tipo de função de ativação para obtermos uma solução que apresente resultados satisfatórios.
#
# Conforme vimos em aula, o desenvolvimento de uma RNA com o Keras é feito segundo as seguintes etapas:
#
# 1. Definição dos dados de treinamento e de teste;
# 2. Configuração da RNA;
# 3. Compilação da RNA, que também inclui a configuração do processo de treinamento pela escolha da função de custo, do otimizador e da métrica para avaliar o desempenho;
# 4. Treinamento da RNA;
# 5. Teste e avaliação do desempenho da RNA.
#
# Observe que a etapa de definição e preparação dos dados já foi realizada.

# %% [markdown]
# ### 4.1 - Configuração da rede neural ##
#
# Vamos configurar, treinar e testar uma primeira rede neural simples de uma camada intermediária usando o Keras.
#
# Para essa rede de uma camada, o parâmetro mais importante é o número de neurônios da camada intermediária. Esse número deve ser compatível com o problema que queremos resolver e também com o número de exemplos que temos disponíveis para treinar a rede.
#
# Em linhas gerais cada imagem é representada por 12.288 números e temos 209 imagens de treinamento. Assim, no conjunto de dados de treinamento temos cerca de 2,6 milhões de valores. Existem um princípio em aprendizado supervisionado que diz que o número de parâmetros do sistema deve ser menor do que o número de valores presente no conjunto de dados utilizado para o treinamento. Assim, a sua rede neural deve ter um número de parâmetros menor do que 2,6 milhões. Se a rede possuir mais parâmetros do que o número de valores presentes no conjunto de dados, ela simplesmente memoriza os dados de treinamento e não funciona direito para nenhum outro caso.
#
# **Qualquer dúvida que você possa ter de como fazer esse trabalho usando o Keras, consulte os slides e o notebook da aula no Moodle**
#
# ### Exercício #4:
#
# Usando o Keras configure uma rede neural com as seguintes caracteríticas:
#
# - uma única camada intermediária com 64 neurônios e função de ativação sigmóide;
# - como queremos resolver um problema de classificação binária a camada de saída deve possuir um único neurônio e ter função de ativação sigmóide.

# %%
# PARA VOCÊ FAZER: configuração de uma RNA rasa

# Importar do Keras classes de modelos e camadas
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

np.random.seed(1) # inicializa gerador de números aleatórios

# Configuração da rede
### COMECE AQUI ### (≈ 3 linhas)
rna = Sequential([
    Dense(64, input_shape=(12288,), activation='relu'),  # Primeira camada densa com 64 unidades e ReLU
    Dense(1, activation='sigmoid')  # Camada de saída com 1 unidade e ativação sigmoide
    ])
### TERMINE AQUI ###

# Visualização da rede
rna.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │         786,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 786,561 (3.00 MB)
#  Trainable params: 786,561 (3.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Saída esperada:**
#
#     Model: "sequential"
#     _________________________________________________________________
#     Layer (type)                 Output Shape              Param #
#     =================================================================
#     dense (Dense)                (None, 64)                786496
#     _________________________________________________________________
#     dense_1 (Dense)              (None, 1)                 65
#     =================================================================
#     Total params: 786,561
#     Trainable params: 786,561
#     Non-trainable params: 0
#     _________________________________________________________________

# %% [markdown]
# ### 4.2 - Compilação e treinamento da rede neural
#
# A segunda e terceira etapas de desenvolvimento da rede no Keras é a sua compilação e treinamento.
#
# ### Exercício #5:
#
# Compile e treine a sua rede neural usando as seguintes opções:
#
# - Método de otimização: gradiente descendente;
# - Função de custo: entropia cruzada;
# - Métrica: exatidão;
# - No treinamento, utilize no método fit o parâmetro batch_size=209, que é o número de exemplos de treinamento;
# - Número de épocas: 10.
#
# Nesse momento estamos treinando a rede somente para verificar se ela é adequada para resolver o problema e se está configurada de forma correta, por isso usamos poucas épocas de treinamento.
#
# Note que para o Keras, certos parâmetros podem ser definidos de formas distintas. Por exemplo, a métrica "Mean Absolute Error" pode ser definida como keras.metrics.MeanAbsoluteError() ou simplesmente pelo string 'mae'.

# %%
# PARA VOCÊ FAZER: configuração do otimizador e treinamento da RNA rasa

# Importar do Keras classe de otimizadores
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

# Compilação da rede
### COMECE AQUI ### (≈ 1 ou 2 linhas)
rna.compile(optimizer=optimizers.SGD(learning_rate=0.01),
            loss=losses.BinaryCrossentropy(),
            metrics=[metrics.BinaryAccuracy()])
### TERMINE AQUI ###

# Teste de treinamento da rede
### COMECE AQUI ### (≈ 1 linha)
rna.fit(train_set_x, train_set_y, epochs=10, batch_size=209)
### TERMINE AQUI ###
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 808ms/step - binary_accuracy: 0.6507 - loss: 0.6996
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - binary_accuracy: 0.3589 - loss: 0.8568
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - binary_accuracy: 0.6555 - loss: 1.2865
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - binary_accuracy: 0.6507 - loss: 0.6547
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.6507 - loss: 0.6479
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.6603 - loss: 0.6406
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.6507 - loss: 0.6353
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.6651 - loss: 0.6307
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - binary_accuracy: 0.6507 - loss: 0.6258
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - binary_accuracy: 0.6555 - loss: 0.6213

# %% [markdown]
# **Saída esperada:**
#
#     Epoch 1/10
#     209/209 [==============================] - 0s 1ms/sample - loss: 0.7257 - acc: 0.3876
#     Epoch 2/10
#     209/209 [==============================] - 0s 272us/sample - loss: 0.6633 - acc: 0.6555
#     Epoch 3/10
#     209/209 [==============================] - 0s 162us/sample - loss: 0.6539 - acc: 0.6459
#     Epoch 4/10
#     209/209 [==============================] - 0s 153us/sample - loss: 0.6515 - acc: 0.6507
#     Epoch 5/10
#     209/209 [==============================] - 0s 153us/sample - loss: 0.6502 - acc: 0.6507
#     Epoch 6/10
#     209/209 [==============================] - 0s 143us/sample - loss: 0.6491 - acc: 0.6507
#     Epoch 7/10
#     209/209 [==============================] - 0s 153us/sample - loss: 0.6481 - acc: 0.6507
#     Epoch 8/10
#     209/209 [==============================] - 0s 166us/sample - loss: 0.6471 - acc: 0.6507
#     Epoch 9/10
#     209/209 [==============================] - 0s 157us/sample - loss: 0.6461 - acc: 0.6507
#     Epoch 10/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6451 - acc: 0.6507
#
# Se o seu resultado é esse ou parecido com esse, você pode conluir que a rede está correta e é capaz de aprender os dados de treinamento. Assim, agora você está pronto para treinar a rede de verdade.
#
# Atenção: É normal que os valores sejam ligeiramente diferentes nesta etapa. Mesmo com seeds aleatórios fixos, algumas etapas do treinamento podem não ser completamente determinísticas.

# %% [markdown]
# ### Exercício #6:
#
# Retreine a sua rede usando 1000 épocas.
#
# Use a opção de **não imprimir** os resultados parciais do treinamento para não gerar tantos dados. No Keras podemos escolher como monitoramos o progresso do treinamento com o parâmetro verbose do método fit, que nos dá as seguintes opções:
#
# - verbose: inteiro = 0, 1, or 2.
# - verbose = 0: silencioso;
# - verbose = 1; barra de progresso (padrão);
# - verbose = 2; uma linha por época.
#
# Guarde os resultados do treinamento para poder fazer um gráfico do processo de treinamento. Se tiver dúvidas, veja no notebook desenvolvido em aula como fazer isso.
#
# Não se esqueça de usar no método fit o parâmetro batch_size=209.
#
# Esse treinamento pode levar alguns minutos. No Google Colab levou cerca de 30 segundossem uso de GPU, mas pode variar dependendo de detalhes da implementação e da carga nos servidores do Colab

# %%
# PARA VOCÊ FAZER: treinamento da RNA por 1000 épocas

### COMECE AQUI ### (≈ 1 linha)
history = rna.fit(train_set_x, train_set_y, epochs=1000, batch_size=209)
### TERMINE AQUI ###
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 0.6507 - loss: 0.6169
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.6555 - loss: 0.6130
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - binary_accuracy: 0.6507 - loss: 0.6094
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.6555 - loss: 0.6065
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.6555 - loss: 0.6034
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - binary_accuracy: 0.6651 - loss: 0.6009
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - binary_accuracy: 0.6555 - loss: 0.5980
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - binary_accuracy: 0.6938 - loss: 0.5963
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - binary_accuracy: 0.6555 - loss: 0.5955
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.6986 - loss: 0.5972
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.6507 - loss: 0.5974
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 0.7560 - loss: 0.5993
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.6507 - loss: 0.5998
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - binary_accuracy: 0.7416 - loss: 0.6010
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.6507 - loss: 0.6023
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 0.7560 - loss: 0.6007
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - binary_accuracy: 0.6507 - loss: 0.5970
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.7656 - loss: 0.5893
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - binary_accuracy: 0.6507 - loss: 0.5817
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 0.7799 - loss: 0.5787
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.6507 - loss: 0.5772
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.7608 - loss: 0.5809
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.6507 - loss: 0.5795
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_accuracy: 0.7703 - loss: 0.5840
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 0.6507 - loss: 0.5788
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 0.7847 - loss: 0.5780
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - binary_accuracy: 0.6555 - loss: 0.5744
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.7895 - loss: 0.5739
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - binary_accuracy: 0.6555 - loss: 0.5689
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.7895 - loss: 0.5685
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - binary_accuracy: 0.6555 - loss: 0.5656
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.7895 - loss: 0.5676
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.6603 - loss: 0.5649
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - binary_accuracy: 0.7990 - loss: 0.5623
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - binary_accuracy: 0.6651 - loss: 0.5607
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.7656 - loss: 0.5669
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - binary_accuracy: 0.6603 - loss: 0.5614
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.7990 - loss: 0.5567
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.6651 - loss: 0.5524
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - binary_accuracy: 0.7799 - loss: 0.5573
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.6651 - loss: 0.5575
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_accuracy: 0.7751 - loss: 0.5580
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.6699 - loss: 0.5487
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 0.7943 - loss: 0.5443
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - binary_accuracy: 0.6699 - loss: 0.5430
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - binary_accuracy: 0.7895 - loss: 0.5473
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - binary_accuracy: 0.6699 - loss: 0.5483
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 0.7751 - loss: 0.5481
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 0.6699 - loss: 0.5420
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 0.7943 - loss: 0.5422
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.6699 - loss: 0.5395
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.8038 - loss: 0.5357
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - binary_accuracy: 0.6794 - loss: 0.5309
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - binary_accuracy: 0.8134 - loss: 0.5300
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 0.6842 - loss: 0.5316
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.7943 - loss: 0.5370
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 0.6746 - loss: 0.5320
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.8086 - loss: 0.5276
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - binary_accuracy: 0.6890 - loss: 0.5279
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.7943 - loss: 0.5302
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 0.6890 - loss: 0.5251
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8134 - loss: 0.5178
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.6986 - loss: 0.5192
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.8038 - loss: 0.5238
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - binary_accuracy: 0.6938 - loss: 0.5204
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.8038 - loss: 0.5152
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - binary_accuracy: 0.6986 - loss: 0.5168
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - binary_accuracy: 0.7990 - loss: 0.5192
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - binary_accuracy: 0.6986 - loss: 0.5189
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 0.7990 - loss: 0.5146
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.6986 - loss: 0.5126
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - binary_accuracy: 0.8086 - loss: 0.5077
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - binary_accuracy: 0.7033 - loss: 0.5044
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.8182 - loss: 0.5031
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - binary_accuracy: 0.7033 - loss: 0.5018
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 0.7990 - loss: 0.5020
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - binary_accuracy: 0.7033 - loss: 0.5026
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8086 - loss: 0.5014
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - binary_accuracy: 0.6986 - loss: 0.5046
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 0.8038 - loss: 0.5040
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - binary_accuracy: 0.6986 - loss: 0.5036
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.8086 - loss: 0.5008
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - binary_accuracy: 0.7033 - loss: 0.4957
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.8230 - loss: 0.4903
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.7033 - loss: 0.4871
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.8278 - loss: 0.4846
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.7033 - loss: 0.4873
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.8134 - loss: 0.4929
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - binary_accuracy: 0.7033 - loss: 0.4911
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - binary_accuracy: 0.8134 - loss: 0.4866
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.7033 - loss: 0.4859
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 0.8182 - loss: 0.4848
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 0.7081 - loss: 0.4831
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.8230 - loss: 0.4794
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.7081 - loss: 0.4772
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8230 - loss: 0.4770
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - binary_accuracy: 0.7129 - loss: 0.4754
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - binary_accuracy: 0.8325 - loss: 0.4737
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.7225 - loss: 0.4711
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - binary_accuracy: 0.8230 - loss: 0.4751
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - binary_accuracy: 0.7177 - loss: 0.4746
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.8278 - loss: 0.4707
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.7225 - loss: 0.4709
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.8278 - loss: 0.4706
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.7177 - loss: 0.4736
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.8278 - loss: 0.4733
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - binary_accuracy: 0.7177 - loss: 0.4702
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - binary_accuracy: 0.8278 - loss: 0.4674
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - binary_accuracy: 0.7273 - loss: 0.4652
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8278 - loss: 0.4617
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.7368 - loss: 0.4631
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - binary_accuracy: 0.8373 - loss: 0.4598
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - binary_accuracy: 0.7273 - loss: 0.4599
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.8278 - loss: 0.4619
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - binary_accuracy: 0.7368 - loss: 0.4629
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.8278 - loss: 0.4608
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.7321 - loss: 0.4587
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.8325 - loss: 0.4527
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - binary_accuracy: 0.7416 - loss: 0.4538
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.8325 - loss: 0.4558
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.7321 - loss: 0.4556
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.8325 - loss: 0.4513
# Epoch 123/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.7464 - loss: 0.4488
# Epoch 124/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.8373 - loss: 0.4514
# Epoch 125/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.7416 - loss: 0.4480
# Epoch 126/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.8421 - loss: 0.4403
# Epoch 127/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.7464 - loss: 0.4422
# Epoch 128/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.8421 - loss: 0.4466
# Epoch 129/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.7321 - loss: 0.4498
# Epoch 130/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 0.8373 - loss: 0.4525
# Epoch 131/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.7464 - loss: 0.4467
# Epoch 132/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - binary_accuracy: 0.8469 - loss: 0.4394
# Epoch 133/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - binary_accuracy: 0.7464 - loss: 0.4355
# Epoch 134/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.8469 - loss: 0.4345
# Epoch 135/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.7560 - loss: 0.4350
# Epoch 136/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.8421 - loss: 0.4378
# Epoch 137/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.7464 - loss: 0.4388
# Epoch 138/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - binary_accuracy: 0.8373 - loss: 0.4396
# Epoch 139/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.7464 - loss: 0.4356
# Epoch 140/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - binary_accuracy: 0.8469 - loss: 0.4331
# Epoch 141/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.7464 - loss: 0.4294
# Epoch 142/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.8565 - loss: 0.4285
# Epoch 143/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.7608 - loss: 0.4252
# Epoch 144/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.8565 - loss: 0.4260
# Epoch 145/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.7560 - loss: 0.4239
# Epoch 146/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.8565 - loss: 0.4253
# Epoch 147/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 0.7656 - loss: 0.4249
# Epoch 148/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - binary_accuracy: 0.8517 - loss: 0.4236
# Epoch 149/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 0.7464 - loss: 0.4282
# Epoch 150/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.8325 - loss: 0.4332
# Epoch 151/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 0.7560 - loss: 0.4284
# Epoch 152/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8517 - loss: 0.4229
# Epoch 153/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 0.7656 - loss: 0.4173
# Epoch 154/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 0.8612 - loss: 0.4147
# Epoch 155/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.7703 - loss: 0.4179
# Epoch 156/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.8517 - loss: 0.4200
# Epoch 157/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 0.7608 - loss: 0.4201
# Epoch 158/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.8469 - loss: 0.4240
# Epoch 159/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.7656 - loss: 0.4182
# Epoch 160/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.8660 - loss: 0.4134
# Epoch 161/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - binary_accuracy: 0.7703 - loss: 0.4091
# Epoch 162/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - binary_accuracy: 0.8565 - loss: 0.4080
# Epoch 163/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.7703 - loss: 0.4106
# Epoch 164/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 0.8517 - loss: 0.4129
# Epoch 165/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.7703 - loss: 0.4105
# Epoch 166/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.8612 - loss: 0.4099
# Epoch 167/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.7751 - loss: 0.4063
# Epoch 168/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.8660 - loss: 0.4039
# Epoch 169/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 0.7799 - loss: 0.4031
# Epoch 170/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 0.8660 - loss: 0.4038
# Epoch 171/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.7799 - loss: 0.4028
# Epoch 172/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - binary_accuracy: 0.8612 - loss: 0.4066
# Epoch 173/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.7751 - loss: 0.4048
# Epoch 174/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.8612 - loss: 0.4030
# Epoch 175/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.7751 - loss: 0.4031
# Epoch 176/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.8612 - loss: 0.4052
# Epoch 177/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.7751 - loss: 0.4061
# Epoch 178/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.8565 - loss: 0.4045
# Epoch 179/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.7895 - loss: 0.3956
# Epoch 180/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - binary_accuracy: 0.8756 - loss: 0.3923
# Epoch 181/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 0.7847 - loss: 0.3915
# Epoch 182/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.8756 - loss: 0.3898
# Epoch 183/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.7943 - loss: 0.3906
# Epoch 184/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.8660 - loss: 0.3951
# Epoch 185/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.7799 - loss: 0.3965
# Epoch 186/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 0.8612 - loss: 0.3947
# Epoch 187/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - binary_accuracy: 0.7943 - loss: 0.3875
# Epoch 188/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8756 - loss: 0.3822
# Epoch 189/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.7943 - loss: 0.3835
# Epoch 190/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.8756 - loss: 0.3881
# Epoch 191/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 0.7895 - loss: 0.3875
# Epoch 192/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.8708 - loss: 0.3870
# Epoch 193/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.7847 - loss: 0.3849
# Epoch 194/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.8756 - loss: 0.3830
# Epoch 195/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 0.7990 - loss: 0.3808
# Epoch 196/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 0.8756 - loss: 0.3790
# Epoch 197/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - binary_accuracy: 0.7895 - loss: 0.3835
# Epoch 198/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.8660 - loss: 0.3891
# Epoch 199/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.7847 - loss: 0.3875
# Epoch 200/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.8708 - loss: 0.3830
# Epoch 201/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.7943 - loss: 0.3797
# Epoch 202/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.8756 - loss: 0.3738
# Epoch 203/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.8038 - loss: 0.3736
# Epoch 204/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.8708 - loss: 0.3741
# Epoch 205/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.7943 - loss: 0.3786
# Epoch 206/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.8708 - loss: 0.3837
# Epoch 207/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.7847 - loss: 0.3801
# Epoch 208/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 0.8708 - loss: 0.3743
# Epoch 209/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.7990 - loss: 0.3703
# Epoch 210/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 0.8756 - loss: 0.3705
# Epoch 211/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.7990 - loss: 0.3682
# Epoch 212/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - binary_accuracy: 0.8756 - loss: 0.3661
# Epoch 213/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.8038 - loss: 0.3658
# Epoch 214/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8756 - loss: 0.3693
# Epoch 215/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.7990 - loss: 0.3685
# Epoch 216/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - binary_accuracy: 0.8708 - loss: 0.3650
# Epoch 217/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - binary_accuracy: 0.8038 - loss: 0.3626
# Epoch 218/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.8756 - loss: 0.3629
# Epoch 219/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.8038 - loss: 0.3621
# Epoch 220/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.8756 - loss: 0.3614
# Epoch 221/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.8086 - loss: 0.3618
# Epoch 222/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - binary_accuracy: 0.8756 - loss: 0.3632
# Epoch 223/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - binary_accuracy: 0.8038 - loss: 0.3637
# Epoch 224/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.8804 - loss: 0.3619
# Epoch 225/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - binary_accuracy: 0.8086 - loss: 0.3604
# Epoch 226/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - binary_accuracy: 0.8852 - loss: 0.3589
# Epoch 227/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - binary_accuracy: 0.8038 - loss: 0.3593
# Epoch 228/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - binary_accuracy: 0.8804 - loss: 0.3584
# Epoch 229/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - binary_accuracy: 0.8086 - loss: 0.3561
# Epoch 230/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - binary_accuracy: 0.8852 - loss: 0.3538
# Epoch 231/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 0.8038 - loss: 0.3556
# Epoch 232/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.8852 - loss: 0.3548
# Epoch 233/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - binary_accuracy: 0.8134 - loss: 0.3516
# Epoch 234/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.8852 - loss: 0.3497
# Epoch 235/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - binary_accuracy: 0.8038 - loss: 0.3526
# Epoch 236/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.8947 - loss: 0.3515
# Epoch 237/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - binary_accuracy: 0.8230 - loss: 0.3482
# Epoch 238/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - binary_accuracy: 0.8900 - loss: 0.3496
# Epoch 239/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.8038 - loss: 0.3509
# Epoch 240/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 0.8947 - loss: 0.3480
# Epoch 241/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - binary_accuracy: 0.8325 - loss: 0.3448
# Epoch 242/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - binary_accuracy: 0.9043 - loss: 0.3432
# Epoch 243/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 0.8182 - loss: 0.3441
# Epoch 244/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.9043 - loss: 0.3417
# Epoch 245/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - binary_accuracy: 0.8421 - loss: 0.3393
# Epoch 246/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9139 - loss: 0.3399
# Epoch 247/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 0.8373 - loss: 0.3409
# Epoch 248/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - binary_accuracy: 0.9043 - loss: 0.3383
# Epoch 249/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - binary_accuracy: 0.8421 - loss: 0.3369
# Epoch 250/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - binary_accuracy: 0.9091 - loss: 0.3379
# Epoch 251/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.8421 - loss: 0.3391
# Epoch 252/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - binary_accuracy: 0.8995 - loss: 0.3377
# Epoch 253/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - binary_accuracy: 0.8469 - loss: 0.3355
# Epoch 254/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 0.9234 - loss: 0.3331
# Epoch 255/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 0.8517 - loss: 0.3319
# Epoch 256/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.9139 - loss: 0.3295
# Epoch 257/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8469 - loss: 0.3304
# Epoch 258/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 0.9234 - loss: 0.3315
# Epoch 259/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.8517 - loss: 0.3303
# Epoch 260/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.9139 - loss: 0.3292
# Epoch 261/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.8469 - loss: 0.3287
# Epoch 262/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9234 - loss: 0.3305
# Epoch 263/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 0.8517 - loss: 0.3296
# Epoch 264/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.9043 - loss: 0.3309
# Epoch 265/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.8421 - loss: 0.3288
# Epoch 266/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 0.9234 - loss: 0.3263
# Epoch 267/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 0.8612 - loss: 0.3209
# Epoch 268/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.9234 - loss: 0.3190
# Epoch 269/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.8565 - loss: 0.3190
# Epoch 270/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9234 - loss: 0.3185
# Epoch 271/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.8660 - loss: 0.3170
# Epoch 272/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 0.9187 - loss: 0.3185
# Epoch 273/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - binary_accuracy: 0.8565 - loss: 0.3206
# Epoch 274/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.9234 - loss: 0.3208
# Epoch 275/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - binary_accuracy: 0.8565 - loss: 0.3190
# Epoch 276/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 0.9139 - loss: 0.3209
# Epoch 277/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.8565 - loss: 0.3188
# Epoch 278/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.9234 - loss: 0.3183
# Epoch 279/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.8660 - loss: 0.3149
# Epoch 280/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9234 - loss: 0.3109
# Epoch 281/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 0.8660 - loss: 0.3099
# Epoch 282/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 0.9234 - loss: 0.3094
# Epoch 283/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.8660 - loss: 0.3067
# Epoch 284/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.9234 - loss: 0.3085
# Epoch 285/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - binary_accuracy: 0.8660 - loss: 0.3091
# Epoch 286/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.9234 - loss: 0.3121
# Epoch 287/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.8660 - loss: 0.3094
# Epoch 288/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9234 - loss: 0.3077
# Epoch 289/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.8660 - loss: 0.3068
# Epoch 290/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.9234 - loss: 0.3066
# Epoch 291/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.8660 - loss: 0.3063
# Epoch 292/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.9234 - loss: 0.3062
# Epoch 293/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.8660 - loss: 0.3032
# Epoch 294/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 0.9234 - loss: 0.3021
# Epoch 295/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 0.8708 - loss: 0.2981
# Epoch 296/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.9282 - loss: 0.2965
# Epoch 297/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.8708 - loss: 0.2958
# Epoch 298/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9234 - loss: 0.2983
# Epoch 299/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.8660 - loss: 0.2989
# Epoch 300/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.9234 - loss: 0.3011
# Epoch 301/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 0.8660 - loss: 0.2975
# Epoch 302/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.9234 - loss: 0.3003
# Epoch 303/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 0.8660 - loss: 0.3009
# Epoch 304/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - binary_accuracy: 0.9234 - loss: 0.3015
# Epoch 305/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.8708 - loss: 0.2942
# Epoch 306/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9234 - loss: 0.2909
# Epoch 307/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 0.8756 - loss: 0.2900
# Epoch 308/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.9282 - loss: 0.2876
# Epoch 309/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.8852 - loss: 0.2841
# Epoch 310/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 0.9234 - loss: 0.2872
# Epoch 311/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.8804 - loss: 0.2868
# Epoch 312/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.9282 - loss: 0.2895
# Epoch 313/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - binary_accuracy: 0.8804 - loss: 0.2865
# Epoch 314/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.9234 - loss: 0.2882
# Epoch 315/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.8756 - loss: 0.2875
# Epoch 316/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.9234 - loss: 0.2897
# Epoch 317/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.8756 - loss: 0.2845
# Epoch 318/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.9234 - loss: 0.2840
# Epoch 319/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - binary_accuracy: 0.8852 - loss: 0.2817
# Epoch 320/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9282 - loss: 0.2800
# Epoch 321/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.8852 - loss: 0.2753
# Epoch 322/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.9282 - loss: 0.2759
# Epoch 323/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.8852 - loss: 0.2767
# Epoch 324/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - binary_accuracy: 0.9282 - loss: 0.2824
# Epoch 325/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.8852 - loss: 0.2812
# Epoch 326/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - binary_accuracy: 0.9234 - loss: 0.2803
# Epoch 327/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.8852 - loss: 0.2798
# Epoch 328/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 0.9282 - loss: 0.2817
# Epoch 329/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.8852 - loss: 0.2787
# Epoch 330/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9234 - loss: 0.2797
# Epoch 331/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.8852 - loss: 0.2767
# Epoch 332/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.9282 - loss: 0.2764
# Epoch 333/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.8852 - loss: 0.2715
# Epoch 334/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9282 - loss: 0.2716
# Epoch 335/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 0.8852 - loss: 0.2675
# Epoch 336/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.9330 - loss: 0.2671
# Epoch 337/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8852 - loss: 0.2651
# Epoch 338/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.9282 - loss: 0.2669
# Epoch 339/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.8852 - loss: 0.2656
# Epoch 340/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.9282 - loss: 0.2674
# Epoch 341/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8852 - loss: 0.2655
# Epoch 342/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.9234 - loss: 0.2704
# Epoch 343/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - binary_accuracy: 0.8852 - loss: 0.2672
# Epoch 344/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - binary_accuracy: 0.9282 - loss: 0.2646
# Epoch 345/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - binary_accuracy: 0.8852 - loss: 0.2611
# Epoch 346/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - binary_accuracy: 0.9282 - loss: 0.2650
# Epoch 347/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - binary_accuracy: 0.8852 - loss: 0.2642
# Epoch 348/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - binary_accuracy: 0.9282 - loss: 0.2651
# Epoch 349/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - binary_accuracy: 0.8900 - loss: 0.2603
# Epoch 350/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.9282 - loss: 0.2633
# Epoch 351/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - binary_accuracy: 0.8852 - loss: 0.2608
# Epoch 352/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - binary_accuracy: 0.9330 - loss: 0.2575
# Epoch 353/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - binary_accuracy: 0.8947 - loss: 0.2550
# Epoch 354/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - binary_accuracy: 0.9378 - loss: 0.2562
# Epoch 355/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - binary_accuracy: 0.8995 - loss: 0.2538
# Epoch 356/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 0.9378 - loss: 0.2563
# Epoch 357/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - binary_accuracy: 0.8947 - loss: 0.2529
# Epoch 358/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.9330 - loss: 0.2569
# Epoch 359/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 0.8947 - loss: 0.2544
# Epoch 360/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - binary_accuracy: 0.9378 - loss: 0.2532
# Epoch 361/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - binary_accuracy: 0.9043 - loss: 0.2482
# Epoch 362/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - binary_accuracy: 0.9426 - loss: 0.2493
# Epoch 363/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8995 - loss: 0.2482
# Epoch 364/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - binary_accuracy: 0.9378 - loss: 0.2491
# Epoch 365/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - binary_accuracy: 0.9091 - loss: 0.2452
# Epoch 366/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9426 - loss: 0.2463
# Epoch 367/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - binary_accuracy: 0.9091 - loss: 0.2432
# Epoch 368/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - binary_accuracy: 0.9378 - loss: 0.2461
# Epoch 369/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 0.9091 - loss: 0.2410
# Epoch 370/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9426 - loss: 0.2423
# Epoch 371/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - binary_accuracy: 0.9091 - loss: 0.2408
# Epoch 372/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.9426 - loss: 0.2404
# Epoch 373/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.9091 - loss: 0.2364
# Epoch 374/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.9474 - loss: 0.2399
# Epoch 375/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - binary_accuracy: 0.9139 - loss: 0.2370
# Epoch 376/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - binary_accuracy: 0.9426 - loss: 0.2389
# Epoch 377/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.9139 - loss: 0.2353
# Epoch 378/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.9474 - loss: 0.2373
# Epoch 379/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.9139 - loss: 0.2361
# Epoch 380/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - binary_accuracy: 0.9474 - loss: 0.2382
# Epoch 381/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 0.9091 - loss: 0.2348
# Epoch 382/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.9474 - loss: 0.2395
# Epoch 383/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.9091 - loss: 0.2371
# Epoch 384/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 0.9426 - loss: 0.2391
# Epoch 385/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.9091 - loss: 0.2344
# Epoch 386/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.9522 - loss: 0.2358
# Epoch 387/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.9139 - loss: 0.2325
# Epoch 388/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.9426 - loss: 0.2355
# Epoch 389/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 0.9139 - loss: 0.2324
# Epoch 390/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.9522 - loss: 0.2345
# Epoch 391/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.9139 - loss: 0.2318
# Epoch 392/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.9474 - loss: 0.2319
# Epoch 393/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.9139 - loss: 0.2291
# Epoch 394/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.9522 - loss: 0.2305
# Epoch 395/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9139 - loss: 0.2266
# Epoch 396/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.9569 - loss: 0.2262
# Epoch 397/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.9139 - loss: 0.2234
# Epoch 398/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.9522 - loss: 0.2243
# Epoch 399/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.9139 - loss: 0.2212
# Epoch 400/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - binary_accuracy: 0.9569 - loss: 0.2250
# Epoch 401/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - binary_accuracy: 0.9139 - loss: 0.2215
# Epoch 402/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9522 - loss: 0.2254
# Epoch 403/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.9139 - loss: 0.2216
# Epoch 404/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.9569 - loss: 0.2211
# Epoch 405/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9187 - loss: 0.2184
# Epoch 406/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - binary_accuracy: 0.9522 - loss: 0.2209
# Epoch 407/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.9139 - loss: 0.2180
# Epoch 408/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.9569 - loss: 0.2191
# Epoch 409/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.9139 - loss: 0.2171
# Epoch 410/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9522 - loss: 0.2202
# Epoch 411/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.9139 - loss: 0.2174
# Epoch 412/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.9522 - loss: 0.2208
# Epoch 413/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.9139 - loss: 0.2174
# Epoch 414/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.9522 - loss: 0.2195
# Epoch 415/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.9139 - loss: 0.2161
# Epoch 416/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.9569 - loss: 0.2178
# Epoch 417/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9234 - loss: 0.2141
# Epoch 418/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.9569 - loss: 0.2125
# Epoch 419/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9234 - loss: 0.2101
# Epoch 420/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9617 - loss: 0.2109
# Epoch 421/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9282 - loss: 0.2073
# Epoch 422/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.9617 - loss: 0.2082
# Epoch 423/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.9378 - loss: 0.2050
# Epoch 424/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.9665 - loss: 0.2080
# Epoch 425/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9378 - loss: 0.2031
# Epoch 426/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.9713 - loss: 0.2017
# Epoch 427/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.9378 - loss: 0.1996
# Epoch 428/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.9665 - loss: 0.2024
# Epoch 429/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.9378 - loss: 0.1994
# Epoch 430/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 0.9713 - loss: 0.2012
# Epoch 431/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.9378 - loss: 0.1994
# Epoch 432/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.9665 - loss: 0.2013
# Epoch 433/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9378 - loss: 0.1975
# Epoch 434/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.9665 - loss: 0.1996
# Epoch 435/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.9378 - loss: 0.1976
# Epoch 436/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.9665 - loss: 0.2002
# Epoch 437/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9378 - loss: 0.1961
# Epoch 438/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - binary_accuracy: 0.9665 - loss: 0.1994
# Epoch 439/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 0.9378 - loss: 0.1973
# Epoch 440/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.9665 - loss: 0.2000
# Epoch 441/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.9378 - loss: 0.1971
# Epoch 442/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9665 - loss: 0.2009
# Epoch 443/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.9378 - loss: 0.1973
# Epoch 444/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.9665 - loss: 0.1989
# Epoch 445/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9378 - loss: 0.1959
# Epoch 446/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 0.9665 - loss: 0.1988
# Epoch 447/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.9378 - loss: 0.1969
# Epoch 448/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 0.9665 - loss: 0.2001
# Epoch 449/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.9378 - loss: 0.1976
# Epoch 450/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.9617 - loss: 0.2007
# Epoch 451/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.9330 - loss: 0.1998
# Epoch 452/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.9665 - loss: 0.2015
# Epoch 453/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 0.9378 - loss: 0.1971
# Epoch 454/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.9617 - loss: 0.1986
# Epoch 455/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.9330 - loss: 0.1988
# Epoch 456/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9617 - loss: 0.2000
# Epoch 457/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9378 - loss: 0.1952
# Epoch 458/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - binary_accuracy: 0.9617 - loss: 0.1961
# Epoch 459/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 0.9378 - loss: 0.1940
# Epoch 460/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.9665 - loss: 0.1947
# Epoch 461/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.9378 - loss: 0.1908
# Epoch 462/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.9665 - loss: 0.1919
# Epoch 463/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.9378 - loss: 0.1880
# Epoch 464/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.9713 - loss: 0.1891
# Epoch 465/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9426 - loss: 0.1835
# Epoch 466/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.9713 - loss: 0.1826
# Epoch 467/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.9474 - loss: 0.1787
# Epoch 468/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 0.9713 - loss: 0.1789
# Epoch 469/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.9569 - loss: 0.1742
# Epoch 470/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.9713 - loss: 0.1738
# Epoch 471/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.9569 - loss: 0.1704
# Epoch 472/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9713 - loss: 0.1723
# Epoch 473/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.9569 - loss: 0.1716
# Epoch 474/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.9713 - loss: 0.1735
# Epoch 475/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.9522 - loss: 0.1720
# Epoch 476/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9713 - loss: 0.1756
# Epoch 477/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 0.9569 - loss: 0.1711
# Epoch 478/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.9713 - loss: 0.1722
# Epoch 479/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.9569 - loss: 0.1688
# Epoch 480/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.9713 - loss: 0.1703
# Epoch 481/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.9569 - loss: 0.1683
# Epoch 482/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.9713 - loss: 0.1707
# Epoch 483/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.9569 - loss: 0.1679
# Epoch 484/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9713 - loss: 0.1703
# Epoch 485/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - binary_accuracy: 0.9569 - loss: 0.1676
# Epoch 486/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 0.9713 - loss: 0.1701
# Epoch 487/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.9569 - loss: 0.1681
# Epoch 488/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.9713 - loss: 0.1712
# Epoch 489/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - binary_accuracy: 0.9569 - loss: 0.1687
# Epoch 490/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.9713 - loss: 0.1716
# Epoch 491/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - binary_accuracy: 0.9522 - loss: 0.1698
# Epoch 492/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - binary_accuracy: 0.9713 - loss: 0.1734
# Epoch 493/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - binary_accuracy: 0.9522 - loss: 0.1701
# Epoch 494/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - binary_accuracy: 0.9713 - loss: 0.1732
# Epoch 495/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9522 - loss: 0.1700
# Epoch 496/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 0.9761 - loss: 0.1724
# Epoch 497/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - binary_accuracy: 0.9569 - loss: 0.1682
# Epoch 498/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 0.9761 - loss: 0.1687
# Epoch 499/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - binary_accuracy: 0.9569 - loss: 0.1651
# Epoch 500/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 0.9761 - loss: 0.1666
# Epoch 501/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - binary_accuracy: 0.9569 - loss: 0.1635
# Epoch 502/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 0.9761 - loss: 0.1647
# Epoch 503/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - binary_accuracy: 0.9569 - loss: 0.1625
# Epoch 504/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9761 - loss: 0.1657
# Epoch 505/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - binary_accuracy: 0.9569 - loss: 0.1623
# Epoch 506/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 0.9761 - loss: 0.1631
# Epoch 507/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - binary_accuracy: 0.9569 - loss: 0.1607
# Epoch 508/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - binary_accuracy: 0.9761 - loss: 0.1639
# Epoch 509/1000
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.9952 - loss: 0.0639
# Epoch 833/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0634
# Epoch 834/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - binary_accuracy: 1.0000 - loss: 0.0634
# Epoch 835/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - binary_accuracy: 1.0000 - loss: 0.0631
# Epoch 836/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 1.0000 - loss: 0.0632
# Epoch 837/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - binary_accuracy: 1.0000 - loss: 0.0628
# Epoch 838/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 1.0000 - loss: 0.0628
# Epoch 839/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.0623
# Epoch 840/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 1.0000 - loss: 0.0624
# Epoch 841/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 1.0000 - loss: 0.0621
# Epoch 842/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 1.0000 - loss: 0.0621
# Epoch 843/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 1.0000 - loss: 0.0616
# Epoch 844/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 1.0000 - loss: 0.0615
# Epoch 845/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0614
# Epoch 846/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 1.0000 - loss: 0.0614
# Epoch 847/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 1.0000 - loss: 0.0610
# Epoch 848/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 1.0000 - loss: 0.0610
# Epoch 849/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 1.0000 - loss: 0.0608
# Epoch 850/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 1.0000 - loss: 0.0608
# Epoch 851/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 1.0000 - loss: 0.0605
# Epoch 852/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 1.0000 - loss: 0.0606
# Epoch 853/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0604
# Epoch 854/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - binary_accuracy: 1.0000 - loss: 0.0605
# Epoch 855/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 1.0000 - loss: 0.0602
# Epoch 856/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0602
# Epoch 857/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 1.0000 - loss: 0.0601
# Epoch 858/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 1.0000 - loss: 0.0601
# Epoch 859/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 1.0000 - loss: 0.0600
# Epoch 860/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 1.0000 - loss: 0.0602
# Epoch 861/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - binary_accuracy: 1.0000 - loss: 0.0600
# Epoch 862/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - binary_accuracy: 1.0000 - loss: 0.0600
# Epoch 863/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 1.0000 - loss: 0.0597
# Epoch 864/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0598
# Epoch 865/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - binary_accuracy: 1.0000 - loss: 0.0594
# Epoch 866/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - binary_accuracy: 1.0000 - loss: 0.0594
# Epoch 867/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 1.0000 - loss: 0.0592
# Epoch 868/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - binary_accuracy: 1.0000 - loss: 0.0593
# Epoch 869/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 1.0000 - loss: 0.0589
# Epoch 870/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 1.0000 - loss: 0.0589
# Epoch 871/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - binary_accuracy: 1.0000 - loss: 0.0585
# Epoch 872/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 1.0000 - loss: 0.0584
# Epoch 873/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 1.0000 - loss: 0.0580
# Epoch 874/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 1.0000 - loss: 0.0579
# Epoch 875/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 1.0000 - loss: 0.0577
# Epoch 876/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_accuracy: 1.0000 - loss: 0.0575
# Epoch 877/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - binary_accuracy: 1.0000 - loss: 0.0573
# Epoch 878/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0572
# Epoch 879/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - binary_accuracy: 1.0000 - loss: 0.0571
# Epoch 880/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 1.0000 - loss: 0.0571
# Epoch 881/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - binary_accuracy: 1.0000 - loss: 0.0568
# Epoch 882/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 1.0000 - loss: 0.0568
# Epoch 883/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - binary_accuracy: 1.0000 - loss: 0.0567
# Epoch 884/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0567
# Epoch 885/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 1.0000 - loss: 0.0565
# Epoch 886/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - binary_accuracy: 1.0000 - loss: 0.0565
# Epoch 887/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 1.0000 - loss: 0.0564
# Epoch 888/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - binary_accuracy: 1.0000 - loss: 0.0565
# Epoch 889/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - binary_accuracy: 1.0000 - loss: 0.0564
# Epoch 890/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 1.0000 - loss: 0.0567
# Epoch 891/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 1.0000 - loss: 0.0565
# Epoch 892/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - binary_accuracy: 1.0000 - loss: 0.0565
# Epoch 893/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 1.0000 - loss: 0.0562
# Epoch 894/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - binary_accuracy: 1.0000 - loss: 0.0562
# Epoch 895/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - binary_accuracy: 1.0000 - loss: 0.0558
# Epoch 896/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - binary_accuracy: 1.0000 - loss: 0.0558
# Epoch 897/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0554
# Epoch 898/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - binary_accuracy: 1.0000 - loss: 0.0554
# Epoch 899/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - binary_accuracy: 1.0000 - loss: 0.0552
# Epoch 900/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - binary_accuracy: 1.0000 - loss: 0.0553
# Epoch 901/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0551
# Epoch 902/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - binary_accuracy: 1.0000 - loss: 0.0551
# Epoch 903/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 1.0000 - loss: 0.0548
# Epoch 904/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 1.0000 - loss: 0.0549
# Epoch 905/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 1.0000 - loss: 0.0547
# Epoch 906/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 1.0000 - loss: 0.0546
# Epoch 907/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 1.0000 - loss: 0.0543
# Epoch 908/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0543
# Epoch 909/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 1.0000 - loss: 0.0541
# Epoch 910/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 1.0000 - loss: 0.0541
# Epoch 911/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.0538
# Epoch 912/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 1.0000 - loss: 0.0537
# Epoch 913/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 1.0000 - loss: 0.0535
# Epoch 914/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 1.0000 - loss: 0.0535
# Epoch 915/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - binary_accuracy: 1.0000 - loss: 0.0532
# Epoch 916/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - binary_accuracy: 1.0000 - loss: 0.0532
# Epoch 917/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0530
# Epoch 918/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 1.0000 - loss: 0.0530
# Epoch 919/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0528
# Epoch 920/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - binary_accuracy: 1.0000 - loss: 0.0527
# Epoch 921/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - binary_accuracy: 1.0000 - loss: 0.0526
# Epoch 922/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - binary_accuracy: 1.0000 - loss: 0.0525
# Epoch 923/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 1.0000 - loss: 0.0523
# Epoch 924/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 1.0000 - loss: 0.0523
# Epoch 925/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 1.0000 - loss: 0.0522
# Epoch 926/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - binary_accuracy: 1.0000 - loss: 0.0522
# Epoch 927/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - binary_accuracy: 1.0000 - loss: 0.0521
# Epoch 928/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - binary_accuracy: 1.0000 - loss: 0.0521
# Epoch 929/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - binary_accuracy: 1.0000 - loss: 0.0520
# Epoch 930/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 1.0000 - loss: 0.0521
# Epoch 931/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0520
# Epoch 932/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0521
# Epoch 933/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 1.0000 - loss: 0.0519
# Epoch 934/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 1.0000 - loss: 0.0519
# Epoch 935/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 1.0000 - loss: 0.0516
# Epoch 936/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 1.0000 - loss: 0.0516
# Epoch 937/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 1.0000 - loss: 0.0514
# Epoch 938/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 1.0000 - loss: 0.0515
# Epoch 939/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 1.0000 - loss: 0.0513
# Epoch 940/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 1.0000 - loss: 0.0512
# Epoch 941/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 1.0000 - loss: 0.0509
# Epoch 942/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - binary_accuracy: 1.0000 - loss: 0.0509
# Epoch 943/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_accuracy: 1.0000 - loss: 0.0507
# Epoch 944/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - binary_accuracy: 1.0000 - loss: 0.0506
# Epoch 945/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - binary_accuracy: 1.0000 - loss: 0.0504
# Epoch 946/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - binary_accuracy: 1.0000 - loss: 0.0503
# Epoch 947/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 1.0000 - loss: 0.0502
# Epoch 948/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 1.0000 - loss: 0.0501
# Epoch 949/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 1.0000 - loss: 0.0499
# Epoch 950/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 1.0000 - loss: 0.0499
# Epoch 951/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - binary_accuracy: 1.0000 - loss: 0.0497
# Epoch 952/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0496
# Epoch 953/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 1.0000 - loss: 0.0495
# Epoch 954/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - binary_accuracy: 1.0000 - loss: 0.0494
# Epoch 955/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - binary_accuracy: 1.0000 - loss: 0.0493
# Epoch 956/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 1.0000 - loss: 0.0493
# Epoch 957/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 1.0000 - loss: 0.0491
# Epoch 958/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 1.0000 - loss: 0.0490
# Epoch 959/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 1.0000 - loss: 0.0489
# Epoch 960/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 1.0000 - loss: 0.0489
# Epoch 961/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 1.0000 - loss: 0.0488
# Epoch 962/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 1.0000 - loss: 0.0487
# Epoch 963/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - binary_accuracy: 1.0000 - loss: 0.0487
# Epoch 964/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 1.0000 - loss: 0.0487
# Epoch 965/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 1.0000 - loss: 0.0486
# Epoch 966/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0487
# Epoch 967/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 1.0000 - loss: 0.0486
# Epoch 968/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0486
# Epoch 969/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0484
# Epoch 970/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0484
# Epoch 971/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 1.0000 - loss: 0.0483
# Epoch 972/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 1.0000 - loss: 0.0483
# Epoch 973/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 1.0000 - loss: 0.0481
# Epoch 974/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 1.0000 - loss: 0.0481
# Epoch 975/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0479
# Epoch 976/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0478
# Epoch 977/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.0476
# Epoch 978/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 1.0000 - loss: 0.0476
# Epoch 979/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - binary_accuracy: 1.0000 - loss: 0.0475
# Epoch 980/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - binary_accuracy: 1.0000 - loss: 0.0474
# Epoch 981/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.0472
# Epoch 982/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - binary_accuracy: 1.0000 - loss: 0.0471
# Epoch 983/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 1.0000 - loss: 0.0470
# Epoch 984/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - binary_accuracy: 1.0000 - loss: 0.0470
# Epoch 985/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 1.0000 - loss: 0.0468
# Epoch 986/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - binary_accuracy: 1.0000 - loss: 0.0468
# Epoch 987/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - binary_accuracy: 1.0000 - loss: 0.0466
# Epoch 988/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 1.0000 - loss: 0.0465
# Epoch 989/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 1.0000 - loss: 0.0464
# Epoch 990/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - binary_accuracy: 1.0000 - loss: 0.0463
# Epoch 991/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - binary_accuracy: 1.0000 - loss: 0.0462
# Epoch 992/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - binary_accuracy: 1.0000 - loss: 0.0461
# Epoch 993/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 1.0000 - loss: 0.0460
# Epoch 994/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0459
# Epoch 995/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - binary_accuracy: 1.0000 - loss: 0.0458
# Epoch 996/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 1.0000 - loss: 0.0457
# Epoch 997/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0456
# Epoch 998/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - binary_accuracy: 1.0000 - loss: 0.0455
# Epoch 999/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0454
# Epoch 1000/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - binary_accuracy: 1.0000 - loss: 0.0453

# %%
# Vamos verificar quais variáveis foram salvas no processo de treinamento
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['binary_accuracy', 'loss'])

# %% [markdown]
# ### 4.3 - Visualização do resultado do treinamento
#
# Para sabermos como o treinamento foi realizado precisamos visualizar a função de custo e a métrica ao longo do processo de treinamento.
#
# ### Exercício #7:
#
# Implemente na célula abaixo a visualização dos resultados do treinamento. Observe que os valores da função de custo e da métrico estão no dicionário history com nomes `'loss'` e `'acc'`. Mas estes nomes podem variar, de acordo com a forma que os parâmetros foram definidos. Verifique a variável history_dict history_dict.keys() para conferir os nomes corretos.
#
# Consulte as notas de aula para relembrar como fazer os gráficos da função de custo e da métrica em função do número de épocas.

# %%
# PARA VOCÊ FAZER: visualização do resultado do treinamento

import matplotlib.pyplot as plt

# Salva custo e exatidão em vetores
custo = history_dict['loss']
exatidao = history_dict['binary_accuracy']

# Cria vetor de épocas
epocas = range(1, len(custo) + 1)

# Gráfico do custo em função das épocas
plt.figure(figsize=(10, 5))
plt.plot(epocas, custo, label='Custo (Perda)')
plt.title('Custo em função das épocas')
plt.xlabel('Épocas')
plt.ylabel('Custo')
plt.legend()
plt.show()

# Gráfico da exatidão em função das épocas
plt.figure(figsize=(10, 5))
plt.plot(epocas, exatidao, label='Exatidão (Acurácia)', color='green')
plt.title('Exatidão em função das épocas')
plt.xlabel('Épocas')
plt.ylabel('Exatidão')
plt.legend()
plt.show()

# %% [markdown]
# **Saída esperada:**
#
# O comportamento esperado para a função de custo durante o treinamento é ela decrescer monotomicamente do início até o final. Para a exatidão, o comportamento esperado é ela aumentar durante o treinamento, apresentando algumas oscilações e alcançando um valor alto no final.
#
# Se você obteve esses resultados, então, a sua rede foi treinada de forma satisfatória e pode-se concluir que ela tem uma capacidade alta para se ajustar aos dados de treinamento.

# %% [markdown]
# ### 4.4 - Avaliação do desempenho da rede neural ###
#
# Após treinar a RNA é importante avaliar o seu desempenho com dados que não foram  utilizados no treinamento. Para isso usamos o dados de teste, que estão nos tensores test_set_x e test_set_y.
#
# ### Exercício #8:
#
# Avalie a sua rede neural calculando os valores da função de custo e da exatidão para os dados de teste usando o método evaluate. Calcule esses valores também para os dados de treinamento para poder fazer comparação.

# %%
# PARA VOCÊ FAZER: calculo do custo e exatidão para os dados de teste

# Usando método evaluate calcule o custo e a exatidão para os dados de treinamento
custo_e_metricas_train = rna.evaluate(train_set_x, train_set_y)
print(f"Custo e exatidão para os dados de treinamento: {custo_e_metricas_train}")

# Usando método evaluate calcule o custo e a exatidão para os dados de teste
custo_e_metricas_test = rna.evaluate(test_set_x, test_set_y)
print(f"Custo e exatidão para os dados de teste: {custo_e_metricas_test}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 1.0000 - loss: 0.0441
# Custo e exatidão para os dados de treinamento: [0.04525377228856087, 1.0]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.7671 - loss: 0.8057
# Custo e exatidão para os dados de teste: [0.7682953476905823, 0.7599999904632568]

# %% [markdown]
# **Resultados esperados:**
#
#     209/209 [==============================] - 0s 656us/sample - loss: 0.3270 - acc: 0.9091
#     [0.3269858589868226, 0.90909094]
#     50/50 [==============================] - 0s 260us/sample - loss: 0.5960 - acc: 0.7000
#     [0.5959848165512085, 0.7]
#
# **Comentários:**
#
# - A exatidação obtida com os dados de treinamento é cerca de 90%, isso significa que a sua rede é satisfatória para resolver esse problema.
#
# - A exatidão obtida com os dados de teste é de cerca de 68%. Esse resultado de fato não é muito bom para essa tarefa simples de classificação.
#
# Analisando esses dados surge uma dúvida. Porque a rede não foi capaz de apresentar um bom desempenho nos dados de teste, se os resultados foram bons nos dados de treinamento?

# %% [markdown]
# ### Exercício #9:
#
# Para avaliar melhor o desepenho da sua rede calcule as saídas previstas dos exemplos do conjunto de teste usando o método predict e a função numpy round faça um gráfico com as classes reais e previstas dos dados do conjunto de teste. Se não souber como fazer consulte as notas de aula e o notebook que desenvolvemos.

# %%
# Usando método predict calcule as classes previstas
yy_prev = rna.predict(test_set_x)

# Transforma saída prevista em números inteiros
yy_prev = np.round(yy_prev).astype(int)

# Gráfico das classes reais e previstas
plt.figure(figsize=(10, 5))
plt.plot(test_set_y[0], 'bo', label='Classes Reais')  # 'bo' indica pontos azuis
plt.plot(yy_prev, 'rx', label='Classes Previstas')   # 'rx' indica cruzes vermelhas
plt.title('Classes Reais vs. Classes Previstas')
plt.xlabel('Exemplos')
plt.ylabel('Classe')
plt.legend()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %% [markdown]
# **Saída esperada:**
#
# Veja a imagem classes_previstas_test.png fornecida com o material do trabalho

# %% [markdown]
# **Comentários:**
#
# - Uma previsão errada de classe pode ser dectada pelos círculos vermelhos, pois quando a classe prevista é igual à classe real o círculo azul é colocado em cima do vermelho tapando-o.
#
# - Provavelmente no grafico devem aparecer mais círculos azuis do que vermelhos indicando que existem mais acertos do que erros na previsão das classes.

# %% [markdown]
# Use o código a seguir, mudando a variável 'index', para você visualizar as imagens e a classe prevista dos exemplos de teste.

# %%
# Exemplo de classificação de uma imagem.
index = 6
plt.imshow(test_set_x[index,:].reshape((num_px, num_px, 3)))
print ("y = " + str(test_set_y[index]) + ", imagem é prevista como sendo uma '" + classes[np.squeeze(yy_prev[index])].decode("utf-8"))
# Out:
# y = [1], imagem é prevista como sendo uma 'non-cat

# %% [markdown]
# **Interpretação dos resultados:**
#
# O custo decrescendo durante o treinamento mostra que os parâmetros estão sendo ajustados de forma a que a rede está aprendendo os dados de treinamento. Como o custo obtido não é muito baixo, então, provavelmente é possível treinar ainda mais a rede para obter melhores resultados nos dados de treinamento.
#
# Tente refazer as etapas 4.2, 4.3 e 4.4, aumentando o número de épocas para algo em torno de 5000, para retreinar a rede. Você verá que o custo de treinamento diminui até praticamente zero e a exatidão aumenta para quase 100%.
#
# **Importante:** só tente treinar com mais épocas após entregar o seu trabalho, pois os resultados esperados são para o treinamento com 1000 épocas.
#
# Contudo, nem sempre é bom treinar a rede até se obter custo perto de zero e exatidão 100% para os dados de treinamento. Em geral quando isso acontece o custo e a exatidão para os dados de teste pioraram. Nesse caso, pode ocorrer que a rede está memorizando os dados de treinamento e não generalizando a solução do problema. Veremos daqui algumas aulas como resolver esse problema. Mas podemos verificar esse fato retreinando a rede para um número maior de épocas.

# %% [markdown]
# ## 5 - Desenvolvimento e teste da rede neural deep-learning ##
#
# Nessa etapa do trabalho você vai configurar, treinar e testar uma rede neural deep learning.
#
# ### Exercício #10:
#
# Usando o Keras configure e crie uma rede neural com as seguintes caracteríticas:
#
# - três camadas intermediárias com função de ativação tipo ReLu;
# - número de neurônios das camadas intermediárias: 64, 32, 16;
# - camada de saída deve possuir um único neurônio e ter função de ativação sigmóide.
#
# Essa rede deve ser criada dentro de uma função (build_model) e os argumentos dessa função são: a dimensão dos dados de entrada e os números de neurônios das diversas camadas.

# %%
# PARA VOCÊ FAZER: configuração da rede deep-learning

# Importar do Keras modelos e camadas
from tensorflow.keras import models
from tensorflow.keras import layers

def build_model(data_shape, n1, n2, n3, n4):
    """
    Essa função configura uma rede neural deep-learning

    Argumentos:
    data_shape = tuple com dimensões dos dados de entrada da rede
    n1 = número de neurônios da primeira camada
    n2 = número de neurônios da segunda camada
    n3 = número de neurônios da terceira camada
    n4 = número de neurônios da camada de saída

    Retorna: modelo da rede neural
    """

    np.random.seed(3)

    model = models.Sequential()

    # Adiciona as camadas ao modelo de RNA
    model.add(layers.Dense(n1, activation='relu', input_shape=data_shape))  # Primeira camada
    model.add(layers.Dense(n2, activation='relu'))  # Segunda camada
    model.add(layers.Dense(n3, activation='relu'))  # Terceira camada
    model.add(layers.Dense(n4, activation='sigmoid'))  # Camada de saída

    return model

# Redefine semente para geração de números aleatórios
np.random.seed(3)

# Dimensão dos dados de entrada
data_shape = (12288,)

# Definição dos números de neurônios das camadas
n1 = 64  # Primeira camada
n2 = 32  # Segunda camada
n3 = 16  # Terceira camada
n4 = 1   # Camada de saída

# Cria rede neural deep learning
rnadl = build_model(data_shape, n1, n2, n3, n4)

# Resumo do modelo
rnadl.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 64)                  │         786,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 789,121 (3.01 MB)
#  Trainable params: 789,121 (3.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Saída esperada:**
#
#     Model: "sequential_1"
#     _________________________________________________________________
#     Layer (type)                 Output Shape              Param #
#     =================================================================
#     dense_2 (Dense)              (None, 64)                786496
#     _________________________________________________________________
#     dense_3 (Dense)              (None, 32)                2080
#     _________________________________________________________________
#     dense_4 (Dense)              (None, 16)                528
#     _________________________________________________________________
#     dense_5 (Dense)              (None, 1)                 17
#     =================================================================
#     Total params: 789,121
#     Trainable params: 789,121
#     Non-trainable params: 0
#     _________________________________________________________________

# %% [markdown]
# ### Exercício #11:
#
# Repita os itens 4.2, 4.3 e 4.4 para a rede neural deep-learning. Use `rnadl` como nome da rede e acrescentando as letras `dl` nas variáveis de custo, exatidao e epocas.
#
# Na célula abaixo compile e treine a sua rede deep-learning para 10 épocas. Esse treinamento é só para verificar se o programa está correto.

# %%
# PARA VOCÊ FAZER: compilação e treinamento da rede deep-learning

# Compilação da rede
rnadl.compile(optimizer=optimizers.SGD(learning_rate=0.01),
              loss=losses.BinaryCrossentropy(),
              metrics=[metrics.BinaryAccuracy()])

# Teste de treinamento da rede
history_dl = rnadl.fit(train_set_x, train_set_y, epochs=10, batch_size=209)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - binary_accuracy: 0.4211 - loss: 0.6974
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.5263 - loss: 0.6879
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.6507 - loss: 0.6589
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.6507 - loss: 0.6502
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.6507 - loss: 0.6468
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 0.6507 - loss: 0.6445
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.6507 - loss: 0.6422
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.6507 - loss: 0.6400
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.6507 - loss: 0.6378
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.6507 - loss: 0.6356

# %% [markdown]
# **Saída esparada:**
#
#     Epoch 1/10
#     209/209 [==============================] - 0s 1ms/sample - loss: 0.7339 - acc: 0.3206
#     Epoch 2/10
#     209/209 [==============================] - 0s 175us/sample - loss: 0.6939 - acc: 0.5072
#     Epoch 3/10
#     209/209 [==============================] - 0s 172us/sample - loss: 0.6786 - acc: 0.5933
#     Epoch 4/10
#     209/209 [==============================] - 0s 191us/sample - loss: 0.6661 - acc: 0.6268
#     Epoch 5/10
#     209/209 [==============================] - 0s 177us/sample - loss: 0.6588 - acc: 0.6316
#     Epoch 6/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6529 - acc: 0.6459
#     Epoch 7/10
#     209/209 [==============================] - 0s 162us/sample - loss: 0.6479 - acc: 0.6507
#     Epoch 8/10
#     209/209 [==============================] - 0s 172us/sample - loss: 0.6433 - acc: 0.6507
#     Epoch 9/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6391 - acc: 0.6555
#     Epoch 10/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6359 - acc: 0.6555

# %% [markdown]
# Na célula abaixo treine a sua rede deep-learning por 1000 épocas. Use verbose = 0 e batch_size = 209.

# %%
# PARA VOCÊ FAZER: treinamento da rede deep-learning por 1000 épocas

### COMECE AQUI ### (≈ 1 linha)
historydl = rnadl.fit(train_set_x, train_set_y, epochs=1000, batch_size=209)

# Vamos verificar quais variáveis foram salvas no processo de treinamento
historydl_dict = historydl.history
historydl_dict.keys()
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - binary_accuracy: 0.6507 - loss: 0.6336
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.6507 - loss: 0.6314
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - binary_accuracy: 0.6507 - loss: 0.6301
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.6507 - loss: 0.6274
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.6507 - loss: 0.6260
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - binary_accuracy: 0.6507 - loss: 0.6239
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.6507 - loss: 0.6224
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.6507 - loss: 0.6204
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.6507 - loss: 0.6187
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.6507 - loss: 0.6170
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - binary_accuracy: 0.6507 - loss: 0.6149
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.6507 - loss: 0.6132
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.6507 - loss: 0.6108
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - binary_accuracy: 0.6507 - loss: 0.6091
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.6507 - loss: 0.6074
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - binary_accuracy: 0.6555 - loss: 0.6061
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.6555 - loss: 0.6037
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.6555 - loss: 0.6026
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.6555 - loss: 0.6002
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.6555 - loss: 0.5991
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.6651 - loss: 0.5967
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.6651 - loss: 0.5954
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.6699 - loss: 0.5933
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.6699 - loss: 0.5917
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.6699 - loss: 0.5896
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.6699 - loss: 0.5880
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.6699 - loss: 0.5856
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.6794 - loss: 0.5840
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.6794 - loss: 0.5817
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.6794 - loss: 0.5811
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.6746 - loss: 0.5790
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.6794 - loss: 0.5778
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.6746 - loss: 0.5748
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.6986 - loss: 0.5741
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.6746 - loss: 0.5713
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.7081 - loss: 0.5696
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.6890 - loss: 0.5674
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.7081 - loss: 0.5658
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.6890 - loss: 0.5641
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - binary_accuracy: 0.7129 - loss: 0.5616
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - binary_accuracy: 0.6890 - loss: 0.5597
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.7129 - loss: 0.5588
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.6890 - loss: 0.5570
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.7321 - loss: 0.5555
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.6842 - loss: 0.5549
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.7368 - loss: 0.5539
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.6746 - loss: 0.5545
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_accuracy: 0.7512 - loss: 0.5539
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.6746 - loss: 0.5539
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.7608 - loss: 0.5489
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.6746 - loss: 0.5501
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.7751 - loss: 0.5477
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.6746 - loss: 0.5489
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.7799 - loss: 0.5465
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.6746 - loss: 0.5478
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.7799 - loss: 0.5439
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.6746 - loss: 0.5457
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.8086 - loss: 0.5419
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.6746 - loss: 0.5433
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 0.8278 - loss: 0.5417
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.6746 - loss: 0.5451
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.8325 - loss: 0.5395
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.6699 - loss: 0.5410
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8278 - loss: 0.5358
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - binary_accuracy: 0.6746 - loss: 0.5389
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.8325 - loss: 0.5352
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.6746 - loss: 0.5373
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.8373 - loss: 0.5335
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.6746 - loss: 0.5385
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - binary_accuracy: 0.8325 - loss: 0.5319
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.6746 - loss: 0.5306
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.8421 - loss: 0.5240
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - binary_accuracy: 0.6746 - loss: 0.5279
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.8373 - loss: 0.5264
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.6746 - loss: 0.5315
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.8660 - loss: 0.5282
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.6746 - loss: 0.5347
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.8469 - loss: 0.5262
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - binary_accuracy: 0.6746 - loss: 0.5245
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.8612 - loss: 0.5164
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - binary_accuracy: 0.6794 - loss: 0.5185
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.8708 - loss: 0.5144
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.6746 - loss: 0.5188
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.8660 - loss: 0.5186
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.6746 - loss: 0.5271
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.8660 - loss: 0.5188
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 0.6746 - loss: 0.5200
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.8612 - loss: 0.5104
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.6890 - loss: 0.5108
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.8756 - loss: 0.5080
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.6890 - loss: 0.5097
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.8708 - loss: 0.5056
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.6890 - loss: 0.5112
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8900 - loss: 0.5106
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.6890 - loss: 0.5113
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.8804 - loss: 0.4997
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - binary_accuracy: 0.6986 - loss: 0.5039
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - binary_accuracy: 0.8900 - loss: 0.5046
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.6842 - loss: 0.5106
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8469 - loss: 0.5059
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.6890 - loss: 0.5116
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.8804 - loss: 0.5044
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 0.6842 - loss: 0.5103
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - binary_accuracy: 0.8612 - loss: 0.5003
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.6986 - loss: 0.4964
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.8900 - loss: 0.4894
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - binary_accuracy: 0.7081 - loss: 0.4909
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.8612 - loss: 0.4887
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.6986 - loss: 0.4924
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.8995 - loss: 0.4880
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.6938 - loss: 0.4978
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.8517 - loss: 0.4989
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.6986 - loss: 0.5012
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.8947 - loss: 0.4886
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.6938 - loss: 0.4991
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.8517 - loss: 0.4936
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.6986 - loss: 0.4944
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.8947 - loss: 0.4856
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.6986 - loss: 0.4927
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.8517 - loss: 0.4918
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - binary_accuracy: 0.6986 - loss: 0.4907
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.8995 - loss: 0.4777
# Epoch 123/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - binary_accuracy: 0.7177 - loss: 0.4785
# Epoch 124/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 0.8708 - loss: 0.4764
# Epoch 125/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.6986 - loss: 0.4823
# Epoch 126/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 0.8947 - loss: 0.4780
# Epoch 127/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.6986 - loss: 0.4904
# Epoch 128/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - binary_accuracy: 0.8373 - loss: 0.4904
# Epoch 129/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_accuracy: 0.6986 - loss: 0.4894
# Epoch 130/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.8995 - loss: 0.4740
# Epoch 131/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.7129 - loss: 0.4777
# Epoch 132/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - binary_accuracy: 0.8756 - loss: 0.4707
# Epoch 133/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - binary_accuracy: 0.7225 - loss: 0.4663
# Epoch 134/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.8995 - loss: 0.4618
# Epoch 135/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 0.7129 - loss: 0.4728
# Epoch 136/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - binary_accuracy: 0.8517 - loss: 0.4737
# Epoch 137/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_accuracy: 0.6986 - loss: 0.4809
# Epoch 138/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - binary_accuracy: 0.8565 - loss: 0.4758
# Epoch 139/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - binary_accuracy: 0.7033 - loss: 0.4837
# Epoch 140/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.8278 - loss: 0.4777
# Epoch 141/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.7129 - loss: 0.4727
# Epoch 142/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 0.8852 - loss: 0.4625
# Epoch 143/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 0.7177 - loss: 0.4591
# Epoch 144/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - binary_accuracy: 0.8900 - loss: 0.4540
# Epoch 145/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.7368 - loss: 0.4525
# Epoch 146/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.8852 - loss: 0.4551
# Epoch 147/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.7225 - loss: 0.4667
# Epoch 148/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - binary_accuracy: 0.8278 - loss: 0.4672
# Epoch 149/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.7129 - loss: 0.4667
# Epoch 150/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.8852 - loss: 0.4571
# Epoch 151/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.7273 - loss: 0.4555
# Epoch 152/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.8517 - loss: 0.4588
# Epoch 153/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - binary_accuracy: 0.7321 - loss: 0.4572
# Epoch 154/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.8660 - loss: 0.4572
# Epoch 155/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 0.7177 - loss: 0.4663
# Epoch 156/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.8278 - loss: 0.4640
# Epoch 157/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.7416 - loss: 0.4534
# Epoch 158/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8804 - loss: 0.4456
# Epoch 159/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.7368 - loss: 0.4455
# Epoch 160/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.8469 - loss: 0.4490
# Epoch 161/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.7464 - loss: 0.4452
# Epoch 162/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.8756 - loss: 0.4423
# Epoch 163/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - binary_accuracy: 0.7321 - loss: 0.4470
# Epoch 164/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.8325 - loss: 0.4540
# Epoch 165/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.7416 - loss: 0.4517
# Epoch 166/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.8804 - loss: 0.4452
# Epoch 167/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.7273 - loss: 0.4505
# Epoch 168/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.8278 - loss: 0.4537
# Epoch 169/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.7464 - loss: 0.4413
# Epoch 170/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.8804 - loss: 0.4358
# Epoch 171/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.7416 - loss: 0.4445
# Epoch 172/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8134 - loss: 0.4533
# Epoch 173/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.7464 - loss: 0.4491
# Epoch 174/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - binary_accuracy: 0.8804 - loss: 0.4358
# Epoch 175/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.7416 - loss: 0.4312
# Epoch 176/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.8469 - loss: 0.4367
# Epoch 177/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.7608 - loss: 0.4273
# Epoch 178/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.8900 - loss: 0.4247
# Epoch 179/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.7416 - loss: 0.4318
# Epoch 180/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.8373 - loss: 0.4343
# Epoch 181/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.7512 - loss: 0.4306
# Epoch 182/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.8804 - loss: 0.4328
# Epoch 183/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.7368 - loss: 0.4378
# Epoch 184/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - binary_accuracy: 0.8325 - loss: 0.4310
# Epoch 185/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.7560 - loss: 0.4283
# Epoch 186/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.8804 - loss: 0.4241
# Epoch 187/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.7464 - loss: 0.4288
# Epoch 188/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.8421 - loss: 0.4276
# Epoch 189/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.7608 - loss: 0.4219
# Epoch 190/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.8852 - loss: 0.4153
# Epoch 191/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.7512 - loss: 0.4189
# Epoch 192/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.8517 - loss: 0.4197
# Epoch 193/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.7608 - loss: 0.4202
# Epoch 194/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.8852 - loss: 0.4188
# Epoch 195/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - binary_accuracy: 0.7464 - loss: 0.4218
# Epoch 196/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.8517 - loss: 0.4160
# Epoch 197/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.7608 - loss: 0.4121
# Epoch 198/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.8947 - loss: 0.4105
# Epoch 199/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 0.7560 - loss: 0.4154
# Epoch 200/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.8469 - loss: 0.4140
# Epoch 201/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 0.7608 - loss: 0.4127
# Epoch 202/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8852 - loss: 0.4113
# Epoch 203/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.7560 - loss: 0.4081
# Epoch 204/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 0.8660 - loss: 0.4094
# Epoch 205/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - binary_accuracy: 0.7608 - loss: 0.4063
# Epoch 206/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8900 - loss: 0.4049
# Epoch 207/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.7560 - loss: 0.4091
# Epoch 208/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8565 - loss: 0.4086
# Epoch 209/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.7608 - loss: 0.4007
# Epoch 210/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8947 - loss: 0.3989
# Epoch 211/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.7560 - loss: 0.3982
# Epoch 212/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.8804 - loss: 0.3980
# Epoch 213/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - binary_accuracy: 0.7608 - loss: 0.3962
# Epoch 214/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.8900 - loss: 0.4006
# Epoch 215/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.7560 - loss: 0.3993
# Epoch 216/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.8900 - loss: 0.3928
# Epoch 217/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.7703 - loss: 0.3881
# Epoch 218/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.8947 - loss: 0.3902
# Epoch 219/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.7560 - loss: 0.3961
# Epoch 220/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.8708 - loss: 0.3939
# Epoch 221/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.7656 - loss: 0.3913
# Epoch 222/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.8852 - loss: 0.3931
# Epoch 223/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.7560 - loss: 0.3869
# Epoch 224/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.8852 - loss: 0.3846
# Epoch 225/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.7703 - loss: 0.3803
# Epoch 226/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.8947 - loss: 0.3832
# Epoch 227/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.7560 - loss: 0.3874
# Epoch 228/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8708 - loss: 0.3871
# Epoch 229/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.7703 - loss: 0.3868
# Epoch 230/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.8947 - loss: 0.3855
# Epoch 231/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.7560 - loss: 0.3874
# Epoch 232/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.8756 - loss: 0.3818
# Epoch 233/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.7703 - loss: 0.3774
# Epoch 234/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.8900 - loss: 0.3799
# Epoch 235/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.7656 - loss: 0.3820
# Epoch 236/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.8852 - loss: 0.3769
# Epoch 237/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 0.7703 - loss: 0.3795
# Epoch 238/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 0.8900 - loss: 0.3816
# Epoch 239/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.7799 - loss: 0.3675
# Epoch 240/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.9139 - loss: 0.3636
# Epoch 241/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.7799 - loss: 0.3632
# Epoch 242/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.8995 - loss: 0.3677
# Epoch 243/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.7656 - loss: 0.3726
# Epoch 244/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.8804 - loss: 0.3726
# Epoch 245/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.7703 - loss: 0.3792
# Epoch 246/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 0.8756 - loss: 0.3809
# Epoch 247/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.7799 - loss: 0.3655
# Epoch 248/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - binary_accuracy: 0.8947 - loss: 0.3622
# Epoch 249/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.7799 - loss: 0.3606
# Epoch 250/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.9043 - loss: 0.3634
# Epoch 251/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.7799 - loss: 0.3623
# Epoch 252/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.8900 - loss: 0.3643
# Epoch 253/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.7751 - loss: 0.3700
# Epoch 254/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - binary_accuracy: 0.8804 - loss: 0.3707
# Epoch 255/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.7895 - loss: 0.3556
# Epoch 256/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.9139 - loss: 0.3509
# Epoch 257/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.8134 - loss: 0.3479
# Epoch 258/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.9091 - loss: 0.3501
# Epoch 259/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.7847 - loss: 0.3569
# Epoch 260/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.8756 - loss: 0.3631
# Epoch 261/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.7799 - loss: 0.3646
# Epoch 262/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8852 - loss: 0.3643
# Epoch 263/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.7943 - loss: 0.3513
# Epoch 264/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9187 - loss: 0.3469
# Epoch 265/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.8134 - loss: 0.3401
# Epoch 266/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.9043 - loss: 0.3444
# Epoch 267/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8038 - loss: 0.3441
# Epoch 268/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.8995 - loss: 0.3485
# Epoch 269/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.7895 - loss: 0.3520
# Epoch 270/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8900 - loss: 0.3525
# Epoch 271/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.8038 - loss: 0.3404
# Epoch 272/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 0.9187 - loss: 0.3384
# Epoch 273/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.8134 - loss: 0.3359
# Epoch 274/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8995 - loss: 0.3436
# Epoch 275/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.7990 - loss: 0.3438
# Epoch 276/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 0.8947 - loss: 0.3466
# Epoch 277/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - binary_accuracy: 0.8134 - loss: 0.3377
# Epoch 278/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 0.9043 - loss: 0.3385
# Epoch 279/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - binary_accuracy: 0.8134 - loss: 0.3297
# Epoch 280/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.9187 - loss: 0.3290
# Epoch 281/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - binary_accuracy: 0.8278 - loss: 0.3183
# Epoch 282/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.9187 - loss: 0.3181
# Epoch 283/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 0.8469 - loss: 0.3116
# Epoch 284/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.9282 - loss: 0.3184
# Epoch 285/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.8182 - loss: 0.3224
# Epoch 286/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - binary_accuracy: 0.9139 - loss: 0.3233
# Epoch 287/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 0.8134 - loss: 0.3295
# Epoch 288/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - binary_accuracy: 0.8995 - loss: 0.3360
# Epoch 289/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.8182 - loss: 0.3227
# Epoch 290/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - binary_accuracy: 0.9139 - loss: 0.3179
# Epoch 291/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 0.8373 - loss: 0.3085
# Epoch 292/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 0.9282 - loss: 0.3074
# Epoch 293/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.8373 - loss: 0.3048
# Epoch 294/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_accuracy: 0.9282 - loss: 0.3078
# Epoch 295/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.8230 - loss: 0.3174
# Epoch 296/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.8995 - loss: 0.3280
# Epoch 297/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.8182 - loss: 0.3244
# Epoch 298/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - binary_accuracy: 0.9234 - loss: 0.3167
# Epoch 299/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 0.8278 - loss: 0.3191
# Epoch 300/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.8852 - loss: 0.3323
# Epoch 301/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.8230 - loss: 0.3175
# Epoch 302/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 0.9234 - loss: 0.3158
# Epoch 303/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - binary_accuracy: 0.8278 - loss: 0.3108
# Epoch 304/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.9043 - loss: 0.3177
# Epoch 305/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 0.8517 - loss: 0.3028
# Epoch 306/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 0.9330 - loss: 0.3021
# Epoch 307/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 0.8373 - loss: 0.2982
# Epoch 308/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 0.9187 - loss: 0.3019
# Epoch 309/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8612 - loss: 0.2939
# Epoch 310/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9282 - loss: 0.2942
# Epoch 311/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - binary_accuracy: 0.8373 - loss: 0.2943
# Epoch 312/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 0.9234 - loss: 0.2932
# Epoch 313/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - binary_accuracy: 0.8469 - loss: 0.2975
# Epoch 314/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.9043 - loss: 0.3067
# Epoch 315/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8278 - loss: 0.3011
# Epoch 316/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.9282 - loss: 0.2943
# Epoch 317/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8517 - loss: 0.2872
# Epoch 318/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.9378 - loss: 0.2865
# Epoch 319/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.8708 - loss: 0.2761
# Epoch 320/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - binary_accuracy: 0.9330 - loss: 0.2787
# Epoch 321/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.8660 - loss: 0.2785
# Epoch 322/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 0.9330 - loss: 0.2773
# Epoch 323/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_accuracy: 0.8708 - loss: 0.2790
# Epoch 324/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.9234 - loss: 0.2893
# Epoch 325/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8421 - loss: 0.2892
# Epoch 326/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.9139 - loss: 0.2941
# Epoch 327/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8373 - loss: 0.2961
# Epoch 328/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.9091 - loss: 0.2938
# Epoch 329/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.8660 - loss: 0.2754
# Epoch 330/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.9426 - loss: 0.2674
# Epoch 331/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.8756 - loss: 0.2631
# Epoch 332/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9426 - loss: 0.2647
# Epoch 333/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.8852 - loss: 0.2609
# Epoch 334/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.9282 - loss: 0.2682
# Epoch 335/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.8708 - loss: 0.2741
# Epoch 336/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.9234 - loss: 0.2789
# Epoch 337/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8421 - loss: 0.2894
# Epoch 338/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.8947 - loss: 0.3028
# Epoch 339/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.8325 - loss: 0.2865
# Epoch 340/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.9330 - loss: 0.2670
# Epoch 341/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.8852 - loss: 0.2554
# Epoch 342/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.9426 - loss: 0.2541
# Epoch 343/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.8900 - loss: 0.2536
# Epoch 344/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - binary_accuracy: 0.9282 - loss: 0.2598
# Epoch 345/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.8756 - loss: 0.2648
# Epoch 346/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.9234 - loss: 0.2732
# Epoch 347/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.8660 - loss: 0.2770
# Epoch 348/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.9187 - loss: 0.2900
# Epoch 349/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.8325 - loss: 0.2916
# Epoch 350/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.8995 - loss: 0.2943
# Epoch 351/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.8756 - loss: 0.2696
# Epoch 352/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - binary_accuracy: 0.9378 - loss: 0.2584
# Epoch 353/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9091 - loss: 0.2428
# Epoch 354/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 0.9474 - loss: 0.2367
# Epoch 355/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.9043 - loss: 0.2346
# Epoch 356/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 0.9426 - loss: 0.2444
# Epoch 357/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - binary_accuracy: 0.8756 - loss: 0.2522
# Epoch 358/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.9282 - loss: 0.2605
# Epoch 359/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.8708 - loss: 0.2702
# Epoch 360/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.9139 - loss: 0.2835
# Epoch 361/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.8612 - loss: 0.2684
# Epoch 362/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9330 - loss: 0.2524
# Epoch 363/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.8947 - loss: 0.2434
# Epoch 364/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9474 - loss: 0.2383
# Epoch 365/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.9139 - loss: 0.2273
# Epoch 366/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 0.9522 - loss: 0.2248
# Epoch 367/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9282 - loss: 0.2248
# Epoch 368/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.9426 - loss: 0.2288
# Epoch 369/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.8947 - loss: 0.2364
# Epoch 370/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9378 - loss: 0.2554
# Epoch 371/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.8612 - loss: 0.2687
# Epoch 372/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.9139 - loss: 0.2790
# Epoch 373/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.8708 - loss: 0.2619
# Epoch 374/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - binary_accuracy: 0.9378 - loss: 0.2574
# Epoch 375/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9139 - loss: 0.2257
# Epoch 376/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9569 - loss: 0.2118
# Epoch 377/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.9330 - loss: 0.2013
# Epoch 378/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.9617 - loss: 0.2012
# Epoch 379/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.9282 - loss: 0.2071
# Epoch 380/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9474 - loss: 0.2229
# Epoch 381/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.8947 - loss: 0.2385
# Epoch 382/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.9234 - loss: 0.2660
# Epoch 383/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 0.8373 - loss: 0.2856
# Epoch 384/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.8852 - loss: 0.3017
# Epoch 385/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.8660 - loss: 0.2622
# Epoch 386/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9426 - loss: 0.2322
# Epoch 387/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9330 - loss: 0.2058
# Epoch 388/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 0.9617 - loss: 0.2002
# Epoch 389/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9330 - loss: 0.1892
# Epoch 390/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.9761 - loss: 0.1849
# Epoch 391/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9282 - loss: 0.1895
# Epoch 392/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9569 - loss: 0.2018
# Epoch 393/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9091 - loss: 0.2190
# Epoch 394/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.9282 - loss: 0.2483
# Epoch 395/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.8565 - loss: 0.2670
# Epoch 396/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.8947 - loss: 0.2815
# Epoch 397/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.8565 - loss: 0.2600
# Epoch 398/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.9426 - loss: 0.2457
# Epoch 399/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.9234 - loss: 0.2020
# Epoch 400/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 0.9761 - loss: 0.1848
# Epoch 401/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - binary_accuracy: 0.9426 - loss: 0.1728
# Epoch 402/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.9761 - loss: 0.1690
# Epoch 403/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 0.9378 - loss: 0.1739
# Epoch 404/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9713 - loss: 0.1817
# Epoch 405/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.9282 - loss: 0.1955
# Epoch 406/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_accuracy: 0.9378 - loss: 0.2245
# Epoch 407/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.8469 - loss: 0.2613
# Epoch 408/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.8660 - loss: 0.3066
# Epoch 409/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - binary_accuracy: 0.8182 - loss: 0.3030
# Epoch 410/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 0.8804 - loss: 0.3000
# Epoch 411/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.8612 - loss: 0.2502
# Epoch 412/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.9522 - loss: 0.2236
# Epoch 413/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.9522 - loss: 0.1703
# Epoch 414/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9809 - loss: 0.1548
# Epoch 415/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9809 - loss: 0.1461
# Epoch 416/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9761 - loss: 0.1414
# Epoch 417/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.9761 - loss: 0.1405
# Epoch 418/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.9761 - loss: 0.1435
# Epoch 419/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.9569 - loss: 0.1530
# Epoch 420/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 0.9713 - loss: 0.1694
# Epoch 421/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - binary_accuracy: 0.9234 - loss: 0.1990
# Epoch 422/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.9091 - loss: 0.2622
# Epoch 423/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 0.8038 - loss: 0.3287
# Epoch 424/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - binary_accuracy: 0.7990 - loss: 0.4077
# Epoch 425/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.8086 - loss: 0.3003
# Epoch 426/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - binary_accuracy: 0.9569 - loss: 0.2356
# Epoch 427/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - binary_accuracy: 0.9665 - loss: 0.1633
# Epoch 428/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - binary_accuracy: 0.9904 - loss: 0.1452
# Epoch 429/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - binary_accuracy: 0.9856 - loss: 0.1349
# Epoch 430/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - binary_accuracy: 0.9856 - loss: 0.1310
# Epoch 431/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - binary_accuracy: 0.9904 - loss: 0.1278
# Epoch 432/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - binary_accuracy: 0.9856 - loss: 0.1262
# Epoch 433/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 0.9856 - loss: 0.1260
# Epoch 434/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - binary_accuracy: 0.9809 - loss: 0.1288
# Epoch 435/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - binary_accuracy: 0.9713 - loss: 0.1357
# Epoch 436/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - binary_accuracy: 0.9713 - loss: 0.1495
# Epoch 437/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.9330 - loss: 0.1762
# Epoch 438/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 0.9282 - loss: 0.2379
# Epoch 439/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 0.8230 - loss: 0.2960
# Epoch 440/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.8038 - loss: 0.4151
# Epoch 441/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - binary_accuracy: 0.7847 - loss: 0.3493
# Epoch 442/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9043 - loss: 0.2903
# Epoch 443/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - binary_accuracy: 0.9665 - loss: 0.1637
# Epoch 444/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - binary_accuracy: 1.0000 - loss: 0.1432
# Epoch 445/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.9952 - loss: 0.1306
# Epoch 446/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 1.0000 - loss: 0.1234
# Epoch 447/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - binary_accuracy: 0.9952 - loss: 0.1194
# Epoch 448/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.1166
# Epoch 449/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - binary_accuracy: 0.9952 - loss: 0.1146
# Epoch 450/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.9952 - loss: 0.1135
# Epoch 451/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 0.9952 - loss: 0.1129
# Epoch 452/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - binary_accuracy: 0.9904 - loss: 0.1131
# Epoch 453/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - binary_accuracy: 0.9904 - loss: 0.1163
# Epoch 454/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - binary_accuracy: 0.9761 - loss: 0.1236
# Epoch 455/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - binary_accuracy: 0.9713 - loss: 0.1356
# Epoch 456/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - binary_accuracy: 0.9617 - loss: 0.1615
# Epoch 457/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 0.9187 - loss: 0.1876
# Epoch 458/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - binary_accuracy: 0.8852 - loss: 0.2709
# Epoch 459/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - binary_accuracy: 0.7895 - loss: 0.3578
# Epoch 460/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 0.7560 - loss: 0.4463
# Epoch 461/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 0.8612 - loss: 0.2541
# Epoch 462/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 0.9761 - loss: 0.1906
# Epoch 463/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.9856 - loss: 0.1394
# Epoch 464/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 1.0000 - loss: 0.1235
# Epoch 465/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 1.0000 - loss: 0.1143
# Epoch 466/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 1.0000 - loss: 0.1092
# Epoch 467/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - binary_accuracy: 1.0000 - loss: 0.1061
# Epoch 468/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 1.0000 - loss: 0.1041
# Epoch 469/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 1.0000 - loss: 0.1025
# Epoch 470/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.1011
# Epoch 471/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 0.9952 - loss: 0.1002
# Epoch 472/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.9952 - loss: 0.0998
# Epoch 473/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 0.9952 - loss: 0.1001
# Epoch 474/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9904 - loss: 0.1021
# Epoch 475/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.9904 - loss: 0.1079
# Epoch 476/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 0.9761 - loss: 0.1210
# Epoch 477/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 0.9474 - loss: 0.1411
# Epoch 478/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.9330 - loss: 0.1957
# Epoch 479/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 0.8517 - loss: 0.2574
# Epoch 480/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 0.7895 - loss: 0.4347
# Epoch 481/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - binary_accuracy: 0.7368 - loss: 0.4814
# Epoch 482/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 0.7512 - loss: 0.4312
# Epoch 483/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 0.9713 - loss: 0.1768
# Epoch 484/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 0.9952 - loss: 0.1458
# Epoch 485/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 1.0000 - loss: 0.1271
# Epoch 486/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - binary_accuracy: 1.0000 - loss: 0.1133
# Epoch 487/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.1055
# Epoch 488/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 1.0000 - loss: 0.1007
# Epoch 489/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - binary_accuracy: 1.0000 - loss: 0.0977
# Epoch 490/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 1.0000 - loss: 0.0956
# Epoch 491/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 1.0000 - loss: 0.0937
# Epoch 492/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 1.0000 - loss: 0.0922
# Epoch 493/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 1.0000 - loss: 0.0908
# Epoch 494/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 1.0000 - loss: 0.0896
# Epoch 495/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - binary_accuracy: 1.0000 - loss: 0.0885
# Epoch 496/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 1.0000 - loss: 0.0876
# Epoch 497/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - binary_accuracy: 1.0000 - loss: 0.0871
# Epoch 498/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 0.9952 - loss: 0.0870
# Epoch 499/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 0.9952 - loss: 0.0876
# Epoch 500/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 0.9952 - loss: 0.0894
# Epoch 501/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.9856 - loss: 0.0934
# Epoch 502/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 0.9952 - loss: 0.0991
# Epoch 503/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - binary_accuracy: 0.9809 - loss: 0.1115
# Epoch 504/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 0.9713 - loss: 0.1265
# Epoch 505/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 0.9569 - loss: 0.1630
# Epoch 506/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 0.9139 - loss: 0.1902
# Epoch 507/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 0.8612 - loss: 0.2976
# Epoch 508/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - binary_accuracy: 0.7656 - loss: 0.4172
# Epoch 509/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 0.7177 - loss: 0.5057
# Epoch 510/1000
# ...
# Epoch 833/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 1.0000 - loss: 0.0172
# Epoch 834/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - binary_accuracy: 1.0000 - loss: 0.0171
# Epoch 835/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - binary_accuracy: 1.0000 - loss: 0.0171
# Epoch 836/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - binary_accuracy: 1.0000 - loss: 0.0170
# Epoch 837/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 1.0000 - loss: 0.0170
# Epoch 838/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0169
# Epoch 839/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0169
# Epoch 840/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - binary_accuracy: 1.0000 - loss: 0.0168
# Epoch 841/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 1.0000 - loss: 0.0167
# Epoch 842/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - binary_accuracy: 1.0000 - loss: 0.0167
# Epoch 843/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 1.0000 - loss: 0.0166
# Epoch 844/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - binary_accuracy: 1.0000 - loss: 0.0165
# Epoch 845/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_accuracy: 1.0000 - loss: 0.0165
# Epoch 846/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - binary_accuracy: 1.0000 - loss: 0.0164
# Epoch 847/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - binary_accuracy: 1.0000 - loss: 0.0164
# Epoch 848/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0163
# Epoch 849/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - binary_accuracy: 1.0000 - loss: 0.0163
# Epoch 850/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - binary_accuracy: 1.0000 - loss: 0.0162
# Epoch 851/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - binary_accuracy: 1.0000 - loss: 0.0162
# Epoch 852/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - binary_accuracy: 1.0000 - loss: 0.0161
# Epoch 853/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 1.0000 - loss: 0.0161
# Epoch 854/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - binary_accuracy: 1.0000 - loss: 0.0160
# Epoch 855/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_accuracy: 1.0000 - loss: 0.0160
# Epoch 856/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - binary_accuracy: 1.0000 - loss: 0.0160
# Epoch 857/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 1.0000 - loss: 0.0159
# Epoch 858/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 1.0000 - loss: 0.0158
# Epoch 859/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 1.0000 - loss: 0.0158
# Epoch 860/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - binary_accuracy: 1.0000 - loss: 0.0157
# Epoch 861/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0157
# Epoch 862/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - binary_accuracy: 1.0000 - loss: 0.0157
# Epoch 863/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 1.0000 - loss: 0.0156
# Epoch 864/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0155
# Epoch 865/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 1.0000 - loss: 0.0155
# Epoch 866/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.0154
# Epoch 867/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 1.0000 - loss: 0.0154
# Epoch 868/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0153
# Epoch 869/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - binary_accuracy: 1.0000 - loss: 0.0153
# Epoch 870/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - binary_accuracy: 1.0000 - loss: 0.0153
# Epoch 871/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - binary_accuracy: 1.0000 - loss: 0.0152
# Epoch 872/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 1.0000 - loss: 0.0152
# Epoch 873/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 1.0000 - loss: 0.0152
# Epoch 874/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 1.0000 - loss: 0.0151
# Epoch 875/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - binary_accuracy: 1.0000 - loss: 0.0151
# Epoch 876/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - binary_accuracy: 1.0000 - loss: 0.0150
# Epoch 877/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - binary_accuracy: 1.0000 - loss: 0.0150
# Epoch 878/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 1.0000 - loss: 0.0149
# Epoch 879/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 1.0000 - loss: 0.0149
# Epoch 880/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0148
# Epoch 881/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 1.0000 - loss: 0.0148
# Epoch 882/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0147
# Epoch 883/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.0146
# Epoch 884/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - binary_accuracy: 1.0000 - loss: 0.0146
# Epoch 885/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - binary_accuracy: 1.0000 - loss: 0.0146
# Epoch 886/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - binary_accuracy: 1.0000 - loss: 0.0145
# Epoch 887/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_accuracy: 1.0000 - loss: 0.0145
# Epoch 888/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0145
# Epoch 889/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0144
# Epoch 890/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 1.0000 - loss: 0.0144
# Epoch 891/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0144
# Epoch 892/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0143
# Epoch 893/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - binary_accuracy: 1.0000 - loss: 0.0143
# Epoch 894/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 1.0000 - loss: 0.0142
# Epoch 895/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - binary_accuracy: 1.0000 - loss: 0.0142
# Epoch 896/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - binary_accuracy: 1.0000 - loss: 0.0141
# Epoch 897/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - binary_accuracy: 1.0000 - loss: 0.0141
# Epoch 898/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0140
# Epoch 899/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 1.0000 - loss: 0.0140
# Epoch 900/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - binary_accuracy: 1.0000 - loss: 0.0139
# Epoch 901/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 1.0000 - loss: 0.0139
# Epoch 902/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - binary_accuracy: 1.0000 - loss: 0.0139
# Epoch 903/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 1.0000 - loss: 0.0139
# Epoch 904/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - binary_accuracy: 1.0000 - loss: 0.0138
# Epoch 905/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - binary_accuracy: 1.0000 - loss: 0.0138
# Epoch 906/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 1.0000 - loss: 0.0137
# Epoch 907/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 1.0000 - loss: 0.0137
# Epoch 908/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - binary_accuracy: 1.0000 - loss: 0.0136
# Epoch 909/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - binary_accuracy: 1.0000 - loss: 0.0136
# Epoch 910/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0136
# Epoch 911/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - binary_accuracy: 1.0000 - loss: 0.0135
# Epoch 912/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 1.0000 - loss: 0.0135
# Epoch 913/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - binary_accuracy: 1.0000 - loss: 0.0134
# Epoch 914/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 1.0000 - loss: 0.0134
# Epoch 915/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0134
# Epoch 916/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0133
# Epoch 917/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 1.0000 - loss: 0.0133
# Epoch 918/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - binary_accuracy: 1.0000 - loss: 0.0133
# Epoch 919/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - binary_accuracy: 1.0000 - loss: 0.0132
# Epoch 920/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - binary_accuracy: 1.0000 - loss: 0.0132
# Epoch 921/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0131
# Epoch 922/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - binary_accuracy: 1.0000 - loss: 0.0131
# Epoch 923/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0131
# Epoch 924/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.0130
# Epoch 925/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - binary_accuracy: 1.0000 - loss: 0.0130
# Epoch 926/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0130
# Epoch 927/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - binary_accuracy: 1.0000 - loss: 0.0129
# Epoch 928/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - binary_accuracy: 1.0000 - loss: 0.0129
# Epoch 929/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - binary_accuracy: 1.0000 - loss: 0.0128
# Epoch 930/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 1.0000 - loss: 0.0128
# Epoch 931/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - binary_accuracy: 1.0000 - loss: 0.0128
# Epoch 932/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - binary_accuracy: 1.0000 - loss: 0.0127
# Epoch 933/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0127
# Epoch 934/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0127
# Epoch 935/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - binary_accuracy: 1.0000 - loss: 0.0126
# Epoch 936/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - binary_accuracy: 1.0000 - loss: 0.0126
# Epoch 937/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - binary_accuracy: 1.0000 - loss: 0.0126
# Epoch 938/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 1.0000 - loss: 0.0126
# Epoch 939/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - binary_accuracy: 1.0000 - loss: 0.0126
# Epoch 940/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0125
# Epoch 941/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 1.0000 - loss: 0.0125
# Epoch 942/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0124
# Epoch 943/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0124
# Epoch 944/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - binary_accuracy: 1.0000 - loss: 0.0123
# Epoch 945/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - binary_accuracy: 1.0000 - loss: 0.0123
# Epoch 946/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 1.0000 - loss: 0.0123
# Epoch 947/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - binary_accuracy: 1.0000 - loss: 0.0122
# Epoch 948/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - binary_accuracy: 1.0000 - loss: 0.0122
# Epoch 949/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0122
# Epoch 950/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - binary_accuracy: 1.0000 - loss: 0.0121
# Epoch 951/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_accuracy: 1.0000 - loss: 0.0121
# Epoch 952/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0121
# Epoch 953/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_accuracy: 1.0000 - loss: 0.0121
# Epoch 954/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0120
# Epoch 955/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 1.0000 - loss: 0.0120
# Epoch 956/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - binary_accuracy: 1.0000 - loss: 0.0120
# Epoch 957/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - binary_accuracy: 1.0000 - loss: 0.0119
# Epoch 958/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_accuracy: 1.0000 - loss: 0.0119
# Epoch 959/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - binary_accuracy: 1.0000 - loss: 0.0119
# Epoch 960/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0118
# Epoch 961/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 1.0000 - loss: 0.0118
# Epoch 962/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 1.0000 - loss: 0.0118
# Epoch 963/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - binary_accuracy: 1.0000 - loss: 0.0117
# Epoch 964/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_accuracy: 1.0000 - loss: 0.0117
# Epoch 965/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - binary_accuracy: 1.0000 - loss: 0.0117
# Epoch 966/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - binary_accuracy: 1.0000 - loss: 0.0116
# Epoch 967/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - binary_accuracy: 1.0000 - loss: 0.0116
# Epoch 968/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0116
# Epoch 969/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - binary_accuracy: 1.0000 - loss: 0.0115
# Epoch 970/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - binary_accuracy: 1.0000 - loss: 0.0115
# Epoch 971/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_accuracy: 1.0000 - loss: 0.0115
# Epoch 972/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - binary_accuracy: 1.0000 - loss: 0.0115
# Epoch 973/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - binary_accuracy: 1.0000 - loss: 0.0114
# Epoch 974/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - binary_accuracy: 1.0000 - loss: 0.0114
# Epoch 975/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - binary_accuracy: 1.0000 - loss: 0.0114
# Epoch 976/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - binary_accuracy: 1.0000 - loss: 0.0114
# Epoch 977/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - binary_accuracy: 1.0000 - loss: 0.0113
# Epoch 978/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - binary_accuracy: 1.0000 - loss: 0.0113
# Epoch 979/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - binary_accuracy: 1.0000 - loss: 0.0112
# Epoch 980/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 1.0000 - loss: 0.0112
# Epoch 981/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - binary_accuracy: 1.0000 - loss: 0.0112
# Epoch 982/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - binary_accuracy: 1.0000 - loss: 0.0112
# Epoch 983/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - binary_accuracy: 1.0000 - loss: 0.0111
# Epoch 984/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 1.0000 - loss: 0.0111
# Epoch 985/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - binary_accuracy: 1.0000 - loss: 0.0111
# Epoch 986/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_accuracy: 1.0000 - loss: 0.0111
# Epoch 987/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - binary_accuracy: 1.0000 - loss: 0.0110
# Epoch 988/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_accuracy: 1.0000 - loss: 0.0110
# Epoch 989/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - binary_accuracy: 1.0000 - loss: 0.0110
# Epoch 990/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - binary_accuracy: 1.0000 - loss: 0.0110
# Epoch 991/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - binary_accuracy: 1.0000 - loss: 0.0109
# Epoch 992/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - binary_accuracy: 1.0000 - loss: 0.0109
# Epoch 993/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - binary_accuracy: 1.0000 - loss: 0.0109
# Epoch 994/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - binary_accuracy: 1.0000 - loss: 0.0108
# Epoch 995/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - binary_accuracy: 1.0000 - loss: 0.0108
# Epoch 996/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - binary_accuracy: 1.0000 - loss: 0.0108
# Epoch 997/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - binary_accuracy: 1.0000 - loss: 0.0108
# Epoch 998/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - binary_accuracy: 1.0000 - loss: 0.0107
# Epoch 999/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - binary_accuracy: 1.0000 - loss: 0.0107
# Epoch 1000/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - binary_accuracy: 1.0000 - loss: 0.0107
# dict_keys(['binary_accuracy', 'loss'])

# %% [markdown]
# ### Exercício #12:
#
# Na célula abaixo introduza os comandos para visualizar os resultados da sua rede deep-learning.

# %%
# PARA VOCÊ FAZER: visualização do resultado do treinamento da rede deep-learning
import matplotlib.pyplot as plt

# Salva custo e exatidão em vetores
custodl = historydl_dict['loss']
exatidaodl = historydl_dict['binary_accuracy']

# Cria vetor de épocas
epocasdl = range(1, len(custodl) + 1)

# Gráfico do custo em função das épocas
plt.figure(figsize=(10, 5))
plt.plot(epocasdl, custodl, label='Custo (Perda)')
plt.title('Custo em função das épocas - Deep Learning')
plt.xlabel('Épocas')
plt.ylabel('Custo')
plt.legend()
plt.show()

# Gráfico da exatidão em função das épocas
plt.figure(figsize=(10, 5))
plt.plot(epocasdl, exatidaodl, label='Exatidão (Acurácia)', color='green')
plt.title('Exatidão em função das épocas - Deep Learning')
plt.xlabel('Épocas')
plt.ylabel('Exatidão')
plt.legend()
plt.show()

# %% [markdown]
# ### Exercício #13:
#
# Na célula abaixo introduza os comandos para avaliar a sua rede deep-learning para os dados de treinamento e de teste.

# %%
# PARA VOCÊ FAZER: calculo do custo e exatidão para os dados de treinamento e de teste para a rede deep-learning

# Usando método evaluate calcule o custo e a exatidão dos dados de treinamento e depois apresente os resultados
custo_e_metricasdl_train = rnadl.evaluate(train_set_x, train_set_y)
print(custo_e_metricasdl_train)

# Usando método evaluate calcule o custo e a exatidão dos dados de teste e depois apresente os resultados
custo_e_metricasdl_test = rnadl.evaluate(test_set_x, test_set_y)
print(custo_e_metricasdl_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 1.0000 - loss: 0.0108
# [0.01065150834619999, 1.0]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.7300 - loss: 1.0593
# [1.0286129713058472, 0.7200000286102295]

# %% [markdown]
# **Saída esperada:**
#
#     209/209 [==============================] - 0s 482us/sample - loss: 0.0115 - acc: 1.0000
#     [0.011545336649320913, 1.0]
#     50/50 [==============================] - 0s 399us/sample - loss: 1.0013 - acc: 0.7400
#     [1.0013008093833924, 0.74]

# %% [markdown]
# ### Exercício #14:
#
# Na célula abaixo introduza os comandos para clcular as classes previstas para os dados de teste.

# %%
# PARA VOCÊ FAZER: calculo das classes previstas dos dados de teste para a rede deep-learning

# Usando método predict calcule as classes previstas
yy_prevdl = rnadl.predict(test_set_x)

# Transforma saída prevista em números inteiros
yy_prevdl = np.round(yy_prevdl).astype(int)

# Gráfico das classes reais e previstas
plt.figure(figsize=(10, 5))
plt.plot(test_set_y[0], 'bo', label='Classes Reais')  # 'bo' indica pontos azuis
plt.plot(yy_prevdl, 'rx', label='Classes Previstas')  # 'rx' indica cruzes vermelhas
plt.title('Classes Reais vs. Classes Previstas - Deep Learning')
plt.xlabel('Exemplos')
plt.ylabel('Classe')
plt.legend()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %% [markdown]
# **Saída esperada:**
#
# O número de erros de classificação é igual a 12 (ou 13), representado por 12 (13) bolinhas vermelhas, o que significa 76% (74%) dos 50 exemplos de teste.
#
# **Interpretação dos resultados:**
#
# Se você fez tudo correto, então, os resultados obtidos do custo e da exatidão para os dados de teste são melhores para a rede neural deep-learning do que para a rede neural rasa, como era de se esperar.
#
# Observe que a rede deep learning possui quase o mesmo número de parâmetros do que a rede rasa, mas obtém resultados mais satisfatórios.
#
# O que fez com que os resultados da rede deep learning fossem muito melhores do que a rede rasa? O número de camadas, o tipo de função de ativação, ou simplesmenete o número de parâmetros?

# %% [markdown]
# <font color='blue'>
#
# **O que é importante lembrar:**
# - A escolha do número de neurônios das camadas da rede é muito importane
# - O tipo de função de ativação usada pode fazer diferença nos resultados
# - Não é uma tarefa fácil desenvolver uma rede neural que apresenta um desempenho bom, mas não é impossível

# %% [markdown]
# ## 6 - Teste as redes que você desenvolveu com sua própria imagem (exercício opcional) ##
#
# Você pode usar qualquer imagem e verificar se as suas redes neurais são eficientes. Para fazer isso faça:
#     1. Clique em "File" na parte superior desse notebook e depois clique "Open" para ir para o seu diretório.
#     2. Adicione a sua imagem nesse diretório.
#     3. Troque o nome do arquivo onde se encontra a imagem no código abaixo.
#     4. Execute o código e verifique se a rede acerta (1 = imagem mostra gato, 0 = imagem não tem gato)!

# %%
# PARA VOCÊ FAZER: teste da rede com suas imagens

## COMECE AQUI ## (coloque o nome do arquivo com a sua imagem)
my_image = path + 'gato-siames.jpg'
## TERMINE AQUI ##

# Pré-processamento da imagem para acertar dimensões.
fname = my_image
image = Image.open(fname)
my_image = image.resize((num_px, num_px), Image.ANTIALIAS)
my_image = np.array(my_image)
my_image = my_image.reshape((1, num_px*num_px*3))
my_image = my_image.astype(float)

# Previsão da rede neural
y_prev_myimage = rnadl.predict(my_image)
my_predicted_image = np.round(y_prev_myimage)
my_predicted_image = my_predicted_image.astype(int)

plt.imshow(image)
print("y = " + str(np.squeeze(my_predicted_image)) + ", sua rede prevê \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# <ipython-input-24-149968509e61>:10: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   my_image = image.resize((num_px, num_px), Image.ANTIALIAS)
# y = 1, sua rede prevê "cat" picture.

# %% [markdown]
# Finalmente, como sugestão, tente fazer alterações de parâmetros e executar o notebook novamente. Mas lembre-se de salvar o seu trabalho em um arquivo pdf e enviar para avaliação antes de modificar o notebook e realizar os seus testes.
#
# Algumas sugestões do que alterar:
#
# - Número de camadas;
# - Número de neurônios nas camadas;
# - Funções de ativação;
# - Tente impor um taxa de aprendizado;
# - Tente outras formas de normalizar os dados.
